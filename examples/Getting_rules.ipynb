# %%
# !pip install dill
# Out:
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (0.3.8)

# %%
# !pip install bnlearn
# Out:
# Requirement already satisfied: bnlearn in /usr/local/lib/python3.10/dist-packages (0.8.8)
# Requirement already satisfied: pgmpy>=0.1.18 in /usr/local/lib/python3.10/dist-packages (from bnlearn) (0.1.25)
# Requirement already satisfied: networkx>=2.7.1 in /usr/local/lib/python3.10/dist-packages (from bnlearn) (3.3)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from bnlearn) (3.7.1)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.10/dist-packages (from bnlearn) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from bnlearn) (2.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bnlearn) (4.66.4)
# Requirement already satisfied: ismember in /usr/local/lib/python3.10/dist-packages (from bnlearn) (1.0.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from bnlearn) (1.2.2)
# Requirement already satisfied: funcsigs in /usr/local/lib/python3.10/dist-packages (from bnlearn) (1.0.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from bnlearn) (0.14.2)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.10/dist-packages (from bnlearn) (0.16)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from bnlearn) (24.1)
# Requirement already satisfied: df2onehot in /usr/local/lib/python3.10/dist-packages (from bnlearn) (1.0.7)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from bnlearn) (2023.6.0)
# Requirement already satisfied: pypickle in /usr/local/lib/python3.10/dist-packages (from bnlearn) (1.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from bnlearn) (0.9.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from bnlearn) (7.7.1)
# Requirement already satisfied: datazets in /usr/local/lib/python3.10/dist-packages (from bnlearn) (0.1.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->bnlearn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->bnlearn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->bnlearn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->bnlearn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->bnlearn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->bnlearn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->bnlearn) (2.8.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pgmpy>=0.1.18->bnlearn) (1.11.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pgmpy>=0.1.18->bnlearn) (2.3.0+cu121)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pgmpy>=0.1.18->bnlearn) (1.4.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from pgmpy>=0.1.18->bnlearn) (3.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from datazets->bnlearn) (2.31.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->bnlearn) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->bnlearn) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->bnlearn) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->bnlearn) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->bnlearn) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->bnlearn) (3.0.11)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bnlearn) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bnlearn) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bnlearn) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->bnlearn) (0.5.6)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->bnlearn) (4.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels->bnlearn) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (6.5.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->datazets->bnlearn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->datazets->bnlearn) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->datazets->bnlearn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->datazets->bnlearn) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (1.12.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy>=0.1.18->bnlearn) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->pgmpy>=0.1.18->bnlearn) (12.5.40)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->bnlearn) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->bnlearn) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->bnlearn) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->pgmpy>=0.1.18->bnlearn) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pgmpy>=0.1.18->bnlearn) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (4.2.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (4.19.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.18.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->bnlearn) (1.2.1)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
# !pip install /content/drive/MyDrive/Train\ expectation\ model\ /Installers/dexire-0.0.1-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/Train expectation model /Installers/dexire-0.0.1-py3-none-any.whl
# dexire is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
from dexire.dexire import DEXiRE
import dexire.dexire as dex

# %%
import json
import os
import numpy as np
import pandas as pd
from scipy import stats
from glob import glob
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import seaborn as sns
import dill
dill.settings['recurse'] = True

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score

# %%
from collections import Counter

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.utils.validation import check_is_fitted
from sklearn.exceptions import NotFittedError
from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA, KernelPCA
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from typing import Tuple
from yellowbrick.cluster import KElbowVisualizer
from pathlib import Path
import pickle
from enum import Enum

class DimensionalityReduction(str, Enum):
    PCA = "PCA"
    TSNE = "TSNE"
    UMAP = "UMAP"
    KernelPCA = "KernelPCA"


class ClusterAnalysis:
    def __init__(self,
                 n_cluster:int=None,
                 normalize: bool = True) -> None:
        self.n_clusters = n_cluster
        self.cluster_model = None
        self.wcss = []
        self.normalize = normalize
        self.scaler = StandardScaler()

    def fit(self, X: np.array, n_clusters: int = None) -> None:
        if n_clusters is not None and n_clusters > 1:
            self.n_clusters = n_clusters
            self.cluster_model = KMeans(n_clusters=n_clusters)
            self.cluster_model.fit(X)

    def predict(self, X: np.array) -> np.array:
        """This function predict

        :param X: _description_
        :type X: np.array
        :raises Exception: _description_
        :return: _description_
        :rtype: np.array
        """
        if self.cluster_model is not None:
            try:
                check_is_fitted(self.cluster_model)
            except NotFittedError as exc:
                print(f"The  model have not been fitted and cannot be used for prediction.")
                raise Exception("The cluster number have not been set. Model cannot be fitted.")
            return self.cluster_model.predict(X)

    def automatically_choose_cluster_numbers(self,
                                             X: np.array,
                                             max_clusters: int = 11) -> bool:
        if self.normalize:
            X = self.scaler.fit_transform(X)
        possible_n_clusters = np.arange(2, max_clusters)
        for i in possible_n_clusters:
            kmeans = KMeans(n_clusters=i, init='k-means++',
                            max_iter=300,
                            n_init=10,
                            random_state=0)
            kmeans.fit(X)
            self.wcss.append(kmeans.inertia_)
        self.plot_elbow(X, max_cluster=max_clusters)
        # Calculate the deltas with first derivate
        delta_wcss = np.diff(self.wcss)
        # Second derivate difference
        delta2_wcss = np.diff(delta_wcss)
        # Find the index of the elbow point
        elbow_index = np.where(delta2_wcss > 0)[0][0] + 2
        best_cluster = possible_n_clusters[elbow_index]
        self.n_clusters = best_cluster
        # fit the model
        self.fit(X, self.n_clusters)
        return True

    def plot_elbow(self,
                   X: np.array,
                   out_file: Path = None,
                   max_cluster: int = 11) -> None:
        kmeans = KMeans()
        visualizer = KElbowVisualizer(kmeans, k=(2, max_cluster))
        visualizer.fit(X)  # Fit the data to the visualizer
        if out_file is not None:
            visualizer.show(outpath=out_file)
        else:
            visualizer.show()

    def plot_clusters(self,
                      X: np.array,
                      y: np.array,
                      dimensionality_reduction: str = DimensionalityReduction.PCA):
        if X.shape[0] != y.shape[0]:
            raise ValueError("X and y have different shapes")
        if dimensionality_reduction == DimensionalityReduction.PCA:
            pca = PCA(n_components=2)
            X_new = pca.fit_transform(X)
        elif dimensionality_reduction == DimensionalityReduction.TSNE:
            tsne = TSNE(n_components=2, random_state=0)
            X_new = tsne.fit_transform(X)
        elif dimensionality_reduction == DimensionalityReduction.UMAP:
            reducer = umap.UMAP(n_components=2, random_state=0)
            X_new = reducer.fit_transform(X)
        elif dimensionality_reduction == DimensionalityReduction.KernelPCA:
            kpca = KernelPCA(n_components=2, kernel='rbf')
            X_new = kpca.fit_transform(X)
        else:
            raise ValueError(f"Dimensionality reduction {dimensionality_reduction} is not supported.")
        fig = plt.figure(figsize=(10, 10))
        ax = fig.add_subplot(1, 1, 1)
        scatter = ax.scatter(
            X_new[:, 0],
            X_new[:, 1],
            c=y,
            cmap='viridis',
            edgecolor='k',
            s=50
        )
        ax.set_title('Clusters')
        ax.set_xlabel('PC1')
        ax.set_ylabel('PC2')
        plt.colorbar(scatter)
        plt.show()

    def save_cluster_model(self, file_path:str):
        # save_cluster_model method
        with open(file_path, 'wb') as f:
            pickle.dump(self.cluster_model, f)

    def load_cluster_model(self, path: str) -> None:
        # load_cluster_model method
        with open(path, 'rb') as f:
            self.cluster_model = pickle.load(f)

# %%
base_path = "/content/drive/MyDrive/Train expectation model /results"

# %% [markdown]
# ## Load recipes

# %%
file_recipes_id = "1EN3b4zt69ItW4G0mg9DQ9OLACS6jO9nY" #"14XbCR2iwjuiHN6XvAKZvbYDkLaWDb0kS" #"11cOxIBXEgHKzDeuWK2RLZaj6UB6b5EE9" "1Fa0pSt3Q2yGhl3X_7dlQaY53Df85dEyW"
downloaded = drive.CreateFile({'id':file_recipes_id})
downloaded.GetContentFile('df_recipes.csv')

# %%
df_recipes = pd.read_csv('df_recipes.csv', sep="|", index_col=0)
df_recipes.head(4)
# Out:
#                     name                                           raw_text  \
# 0            Fruit Salad  1. Fruit Salad: 70 calories per portion, 4 por...
# 1         Vegan Omelette  5. Vegan Omelette: 300 calories per portion, 1...
# 2     Vegan French Toast  7. Vegan French Toast: 400 calories per portio...
# 3  Granola with Soy Milk  10. Granola with Soy Milk: 550 calories per po...
#
#   cultural_restriction  calories     allergens recipeId  \
# 0                vegan      70.0  NotAllergens   food_0
# 1                vegan     300.0       legumes   food_4
# 2                vegan     400.0  NotAllergens   food_6
# 3                vegan     550.0     tree nuts   food_9
#
#                                          ingredients  \
# 0  ingredients:\n- 1 apple\n- 1 banana\n- 1 orang...
# 1  ingredients:\n- 1 cup chickpea flour\n- 1 cup ...
# 2  ingredients:\n- 4 slices of vegan bread\n- 1 c...
# 3  ingredients:\n- 3 cups rolled oats\n- 1 cup nu...
#
#                                         instructions  carbohydrates   fat  \
# 0  \n1. wash and cut all the fruits into bite-siz...          223.0   2.0
# 1  \n1. in a mixing bowl, whisk together the chic...          100.0  20.5
# 2  \n1. in a shallow dish, whisk together the alm...          115.0  38.5
# 3  \n1. preheat your oven to 325°f (165°c).\n2. i...           13.1  26.0
#
#    fiber  protein  taste cooking_style    meal_type  prep_time  \
# 0    0.0     15.0  sweet         mixed  fruit-based       15.0
# 1    6.0     15.0  salty       sauteed       veggie       20.0
# 2   11.8     17.0  sweet       sauteed        vegan       25.0
# 3    1.5      5.5  sweet         baked  grain-based       25.0
#
#            cuisine  price                                   ingredients_list
# 0    International    2.0  apple, banana, orange, grape, strawberry, pine...
# 1          , Vegan    2.0  chickpea, flour, water, yeast, turmeric, garli...
# 2  , French, Vegan    1.0  vegan, bread, unsweetened, almond, milk, groun...
# 3    International    2.0  rolled, oat, nut, almond, walnut, pecan, dried...

# %%
df_recipes.shape
# Out:
# (7017, 19)

# %%
# fill nan in columns
def check_nans(df_test):
  dict_col_nans = {}
  for col in df_test.columns:
    dict_col_nans[col] = sum(df_test[col].isna())
  return dict_col_nans

# %%
#Check recipes
check_nans(df_recipes)
# Out:
# {'name': 0,
#  'raw_text': 0,
#  'cultural_restriction': 0,
#  'calories': 0,
#  'allergens': 0,
#  'recipeId': 0,
#  'ingredients': 0,
#  'instructions': 0,
#  'carbohydrates': 0,
#  'fat': 0,
#  'fiber': 0,
#  'protein': 0,
#  'taste': 0,
#  'cooking_style': 0,
#  'meal_type': 0,
#  'prep_time': 0,
#  'cuisine': 0,
#  'price': 0,
#  'ingredients_list': 0}

# %% [markdown]
# ## Load Datasets

# %%
# Replace the file ID with your own
file_id_train = "1NgfU1fHmA85jNOSC8OshNq2SxFJx_j9r" #'1RAN4QQNJm5g1GEsqZW3KbTdeYOxPkyJ2' https://drive.google.com/file/d/1NgfU1fHmA85jNOSC8OshNq2SxFJx_j9r/view?usp=drive_link
file_id_val = "1HelnJeFj0GiAGI3Fi7pFscULDY1SMOtC" #'1kES6RWac8K0HKbCaP_9FFF2Bca7a7pht' https://drive.google.com/file/d/1HelnJeFj0GiAGI3Fi7pFscULDY1SMOtC/view?usp=drive_link
file_id_test = "1GPpJNn4OdNs_Bkg3d1nnUooAoPoCqsdO" #'1LzS9puUVI2xQIIyVI-FK0Rpa8C2MmHdH' https://drive.google.com/file/d/1GPpJNn4OdNs_Bkg3d1nnUooAoPoCqsdO/view?usp=drive_link
link = 'https://drive.google.com/uc?id={file_id}'

# %%
# Train
downloaded = drive.CreateFile({'id':file_id_train})
downloaded.GetContentFile('train.csv')

# val
downloaded = drive.CreateFile({'id':file_id_val})
downloaded.GetContentFile('val.csv')

# Test
downloaded = drive.CreateFile({'id':file_id_test})
downloaded.GetContentFile('test.csv')

# %%
train = pd.read_csv('train.csv', sep="|", index_col=0)
print(train.shape)
val = pd.read_csv("val.csv",  sep="|", index_col=0)
print(val.shape)
test = pd.read_csv('test.csv',  sep="|", index_col=0)
print(test.shape)
# Out:
# (1024002, 47)
# (204800, 47)
# (51201, 47)

# %%
train['cultural_factor'].fillna("NotRestriction", inplace=True)
val['cultural_factor'].fillna("NotRestriction", inplace=True)
test['cultural_factor'].fillna("NotRestriction", inplace=True)

# %%
train['allergy'].fillna("NotAllergy", inplace=True)
val['allergy'].fillna("NotAllergy", inplace=True)
test['allergy'].fillna("NotAllergy", inplace=True)

# %%
check_nans(train)
# Out:
# {'day_number': 0,
#  'meal_type_x': 0,
#  'userId': 0,
#  'foodId': 0,
#  'time_of_meal_consumption': 0,
#  'place_of_meal_consumption': 0,
#  'social_situation_of_meal_consumption': 0,
#  'appreciation_feedback': 0,
#  'nutrition_goal': 0,
#  'clinical_gender': 0,
#  'age_range': 0,
#  'life_style': 0,
#  'weight': 0,
#  'height': 0,
#  'projected_daily_calories': 0,
#  'current_daily_calories': 0,
#  'country_of_origin': 0,
#  'living_country': 0,
#  'current_location': 0,
#  'cultural_factor': 0,
#  'probabilities': 811974,
#  'allergy': 0,
#  'Multi-allergy': 921530,
#  'current_working_status': 0,
#  'marital_status': 0,
#  'ethnicity': 0,
#  'BMI': 0,
#  'next_BMI': 0,
#  'name': 0,
#  'raw_text': 0,
#  'cultural_restriction': 0,
#  'calories': 0,
#  'allergens': 0,
#  'recipeId': 0,
#  'ingredients': 0,
#  'instructions': 0,
#  'carbohydrates': 0,
#  'fat': 0,
#  'fiber': 0,
#  'protein': 0,
#  'taste': 0,
#  'cooking_style': 0,
#  'meal_type_y': 0,
#  'prep_time': 0,
#  'cuisine': 0,
#  'price': 0,
#  'ingredients_list': 0}

# %%
check_nans(val)
# Out:
# {'day_number': 0,
#  'meal_type_x': 0,
#  'userId': 0,
#  'foodId': 0,
#  'time_of_meal_consumption': 0,
#  'place_of_meal_consumption': 0,
#  'social_situation_of_meal_consumption': 0,
#  'appreciation_feedback': 0,
#  'nutrition_goal': 0,
#  'clinical_gender': 0,
#  'age_range': 0,
#  'life_style': 0,
#  'weight': 0,
#  'height': 0,
#  'projected_daily_calories': 0,
#  'current_daily_calories': 0,
#  'country_of_origin': 0,
#  'living_country': 0,
#  'current_location': 0,
#  'cultural_factor': 0,
#  'probabilities': 162083,
#  'allergy': 0,
#  'Multi-allergy': 184731,
#  'current_working_status': 0,
#  'marital_status': 0,
#  'ethnicity': 0,
#  'BMI': 0,
#  'next_BMI': 0,
#  'name': 0,
#  'raw_text': 0,
#  'cultural_restriction': 0,
#  'calories': 0,
#  'allergens': 0,
#  'recipeId': 0,
#  'ingredients': 0,
#  'instructions': 0,
#  'carbohydrates': 0,
#  'fat': 0,
#  'fiber': 0,
#  'protein': 0,
#  'taste': 0,
#  'cooking_style': 0,
#  'meal_type_y': 0,
#  'prep_time': 0,
#  'cuisine': 0,
#  'price': 0,
#  'ingredients_list': 0}

# %%
check_nans(test)
# Out:
# {'day_number': 0,
#  'meal_type_x': 0,
#  'userId': 0,
#  'foodId': 0,
#  'time_of_meal_consumption': 0,
#  'place_of_meal_consumption': 0,
#  'social_situation_of_meal_consumption': 0,
#  'appreciation_feedback': 0,
#  'nutrition_goal': 0,
#  'clinical_gender': 0,
#  'age_range': 0,
#  'life_style': 0,
#  'weight': 0,
#  'height': 0,
#  'projected_daily_calories': 0,
#  'current_daily_calories': 0,
#  'country_of_origin': 0,
#  'living_country': 0,
#  'current_location': 0,
#  'cultural_factor': 0,
#  'probabilities': 40676,
#  'allergy': 0,
#  'Multi-allergy': 46185,
#  'current_working_status': 0,
#  'marital_status': 0,
#  'ethnicity': 0,
#  'BMI': 0,
#  'next_BMI': 0,
#  'name': 0,
#  'raw_text': 0,
#  'cultural_restriction': 0,
#  'calories': 0,
#  'allergens': 0,
#  'recipeId': 0,
#  'ingredients': 0,
#  'instructions': 0,
#  'carbohydrates': 0,
#  'fat': 0,
#  'fiber': 0,
#  'protein': 0,
#  'taste': 0,
#  'cooking_style': 0,
#  'meal_type_y': 0,
#  'prep_time': 0,
#  'cuisine': 0,
#  'price': 0,
#  'ingredients_list': 0}

# %% [markdown]
# ## Load word embeddings

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
# Choose the embedding to load and
class ChooseFromDict:
  def __init__(self, options_dict, description):
    self.options_dict = options_dict
    # create selector
    layout = widgets.Layout(width='auto', height='40px') #set width and height
    self.selector = widgets.Dropdown(
    options=self.options_dict.keys(),
    description=description,
    # layout= layout
    )
    # selected embedding
    self.selected_value = self.selector.value
    self.value = self.options_dict[self.selected_value]
    self.loaded_value = None
    self.out = widgets.Output()
    self.selector.observe(self.on_change, names='value')

  def on_change(self, change):
    with self.out:
      print(f"Selected: {change['new']}")
    new_val = change['new']
    self.selected_value = new_val
    self.value = self.options_dict[new_val]
    with self.out:
      print("loading...")
    self.load_embedding()

  def load_embedding(self):
    self.loaded_value = dict(np.load(self.value))
    with self.out:
      print(f"Embedding size: {len(self.loaded_value)}")

  def display(self):
    self.out.clear_output()
    with self.out:
      display(self.selector)
    return self.out


embedding_list = ['cbow', 'skip', 'doc2vec', 'use', 'bert']
paths = [
    "/content/drive/MyDrive/Train expectation model /results/cbow_recipe_embedding_v2_17_may.npz",
    "/content/drive/MyDrive/Train expectation model /results/skip_recipe_embedding_v2_17_may.npz",
    "/content/drive/MyDrive/Train expectation model /results/doc2vec_embedding_v2_17_may.npz",
    "/content/drive/MyDrive/Train expectation model /results/full_recipes_sentence_embedding_USE_v3.npz",
    "/content/drive/MyDrive/Train expectation model /results/full_recipe_embedding_BERT_v2_17_may_recipeId.npz"
]
selection_dict = dict(zip(embedding_list, paths))

chosser = ChooseFromDict(selection_dict, "Choose the embedding:")

# selector_embedding = widgets.Dropdown(
#     options=embedding_list,
#     description="Choose the embedding:"
# )
# selected_key = ""
# dict_embedding_cbow = None

# def on_change(change):
#   key = change['new']
#   path = selection_dict[key]
#   dict_embeddings_cbow = dict(np.load(path))
#   selected_key = key
#   print(f"Embedding size: {len(dict_embeddings_cbow)}")

# selector_embedding.observe(on_change, names='value')
# display(selector_embedding)

# %%
chosser.display()
# Out:
# Output()

# %% [markdown]
# ## Dataset preprocessing and preparation

# %%
def generate_supervision(vector_row: np.array):
  index = np.argmax(vector_row)
  if index < 2:
    return 0.0
  else:
    return 1.0

# %%
def generate_label(value: float):
  if value >= 0.5:
    return 1.0
  else:
    return 0.0

# %%
# load full models
dir_list = glob(os.path.join(base_path, "rules","new_experiments_2", "*/"), recursive = True)

# %%
dir_list
# Out:
# ['/content/drive/MyDrive/Train expectation model /results/rules/new_experiments_2/cbow/',
#  '/content/drive/MyDrive/Train expectation model /results/rules/new_experiments_2/skip/',
#  '/content/drive/MyDrive/Train expectation model /results/rules/new_experiments_2/doc2vec/',
#  '/content/drive/MyDrive/Train expectation model /results/rules/new_experiments_2/use/',
#  '/content/drive/MyDrive/Train expectation model /results/rules/new_experiments_2/bert/']

# %%
dir_list[-1]
# Out:
# '/content/drive/MyDrive/Train expectation model /results/rules/new_experiments_2/bert/'

# %%
rule_list = glob(os.path.join(dir_list[-1], '*.pkl'))

# %%
# load one rule set
rule_set = None
with open(rule_list[0], 'rb') as fp:
  rule_set = dill.load(fp)

# %%
# load data
chosen_embedding = chosser.selected_value
idx = 0
model_type = "Full_model"
path_to_data = os.path.join(base_path, "experimental_data", f"experimental_data_{chosen_embedding}_{idx}_{model_type}.npz")
data = np.load(path_to_data)
x_te_xai = data["x_te_xai"]
feature_name = data["feat_names"]
data_indices = data["test_index"]
y_te_rules = data["y_te_rules"]
data.close()

# %%
# data preprocessing
numeric_features = ['calories',
 'carbohydrates',
 'current_daily_calories',
 'fat',
 'fiber',
 'height',
 'price',
 'projected_daily_calories',
 'protein',
 'weight',
'day_number',
'time_of_meal_consumption']
categorical_features = [
  'BMI',
  'age_range',
  'allergens',
  'allergy',
  'clinical_gender',
  'cultural_factor',
  'cultural_restriction',
  'current_working_status',
  'ethnicity',
  'life_style',
  'marital_status',
  'next_BMI',
  'nutrition_goal',
  'meal_type_y',
  'taste',
  'place_of_meal_consumption',
  'social_situation_of_meal_consumption'
 ]
embedding_features = ['cluster']

# %%
selected_df = test.loc[data_indices]

# %%
selected_df.shape
# Out:
# (5108, 47)

# %%
selected_df["y_pred"] = y_te_rules

# %%
# negative
dislike_mask = selected_df["y_pred"] == 0
print(f"dislike: {sum(dislike_mask)}")
# positive
like_mask = selected_df["y_pred"] == 1
print(f"like: {sum(like_mask)}")
# Out:
# dislike: 1529
# like: 3579

# %%
users = selected_df["userId"].unique()

# %%
test_user = users[0]

# %%
df_user = selected_df.loc[selected_df["userId"]==test_user, :]

# %%
dislike_np_index = np.where(y_te_rules == 0)[0]
like_np_index = np.where(y_te_rules == 1)[0]

# %%
test_xai_dislike = x_te_xai[dislike_np_index, :]
test_xai_like = x_te_xai[like_np_index[:3], :]

# %%
rule_path_dislike = rule_set.predict_numpy_rules(test_xai_dislike, return_decision_path=True)
rule_path_like = rule_set.predict_numpy_rules(test_xai_like, return_decision_path=True)

# %%
like_dict_rules = dict(zip(like_np_index[:3], rule_path_like[1]))

# %%
dislike_dict_rules = dict(zip(dislike_np_index, rule_path_dislike[1]))

# %%
like_dict_rules
# Out:
# {2: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories > -0.018) AND (scaler__fat > -0.464) AND (scaler__fiber <= 1.225) AND (onehot__allergens_legumes <= 0.5) AND (onehot__meal_type_y_breakfast <= 0.5) AND (onehot__allergens_sesame <= 0.5) AND (scaler__fat <= 3.082) AND (cluster > 1.5) AND (scaler__carbohydrates <= 2.143) AND (onehot__allergens_peanuts <= 0.5) AND (scaler__fat <= 0.284) AND (scaler__protein > -0.615) AND (scaler__fiber > -0.919) AND (scaler__carbohydrates > -0.747) AND (scaler__fiber <= 0.346) AND (scaler__fat <= 0.13) AND (scaler__calories <= 0.382) AND (onehot__meal_type_y_vegan <= 0.5)) THEN 1],
#  3: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat <= 0.195) AND (scaler__carbohydrates <= 0.912) AND (onehot__allergens_soy <= 0.5) AND (scaler__protein <= -0.121) AND (onehot__meal_type_y_vegetarian <= 0.5) AND (onehot__meal_type_y_meat_based <= 0.5) AND (onehot__meal_type_y_smoothie <= 0.5) AND (onehot__allergens_sesame <= 0.5) AND (onehot__taste_bitter <= 0.5) AND (cluster > 1.5) AND (onehot__allergens_nightshade <= 0.5) AND (onehot__allergens_peanuts <= 0.5) AND (scaler__calories <= -0.192) AND (scaler__carbohydrates > -0.233) AND (scaler__protein <= -0.2) AND (scaler__day_number <= 1.689) AND (scaler__calories <= -0.49)) THEN 1],
#  4: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein <= -0.27)) THEN 1]}

# %%
selected_df.loc[data_indices[4], :]
# Out:
# day_number                                                                            384
# meal_type_x                                                                        dinner
# userId                                                                          casey9b1c
# foodId                                                                            food_24
# time_of_meal_consumption                                                         17.78223
# place_of_meal_consumption                                                            home
# social_situation_of_meal_consumption                                                alone
# appreciation_feedback                                                            0.650034
# nutrition_goal                                                               maintain_fit
# clinical_gender                                                                         F
# age_range                                                                           50-59
# life_style                                                                    Very active
# weight                                                                               71.1
# height                                                                                184
# projected_daily_calories                                                           2731.0
# current_daily_calories                                                             2731.0
# country_of_origin                                                                 Reunion
# living_country                                                                    Ireland
# current_location                                                                   fil_PH
# cultural_factor                                                           flexi_observant
# probabilities                                                            flexi_vegetarian
# allergy                                                                             wheat
# Multi-allergy                                                                         NaN
# current_working_status                                                   Full-time-worker
# marital_status                                                                    Married
# ethnicity                                                                           White
# BMI                                                                               healthy
# next_BMI                                                                       overweight
# name                                                              Vegan Breakfast Muffins
# raw_text                                25. Vegan Breakfast Muffins: 450 calories per ...
# cultural_restriction                                                                vegan
# calories                                                                            450.0
# allergens                                                                       tree nuts
# recipeId                                                                          food_24
# ingredients                             ingredients: \n- 1 1/2 cups all-purpose flour\...
# instructions                            \n1. preheat your oven to 350°f (180°c) and li...
# carbohydrates                                                                       305.0
# fat                                                                                  92.5
# fiber                                                                                 2.6
# protein                                                                              3.25
# taste                                                                               sweet
# cooking_style                                                                       baked
# meal_type_y                                                                    vegetarian
# prep_time                                                                            30.0
# cuisine                                                                             Vegan
# price                                                                                 2.0
# ingredients_list                        flour, rolled, oat, brown, sugar, baking, powd...
# y_pred                                                                                  1
# Name: 312602, dtype: object

# %%
dislike_dict_rules
# Out:
# {0: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  18: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  19: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  21: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  25: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  34: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  36: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  38: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  39: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  43: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  48: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  53: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  55: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  57: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  58: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  60: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  62: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  63: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  65: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  67: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  76: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  79: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  80: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  81: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  83: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  84: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  85: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories > 0.647)) THEN 0],
#  90: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  97: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  117: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  118: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  120: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  122: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates <= -0.773)) THEN 0],
#  135: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates <= -0.773)) THEN 0],
#  141: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  144: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  146: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  148: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  152: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  153: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein > 1.324)) THEN 0],
#  154: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat > 0.195)) THEN 0],
#  155: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat <= 0.195) AND (scaler__carbohydrates > 0.912)) THEN 0],
#  157: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  158: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  159: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  165: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories > 0.647)) THEN 0],
#  166: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  173: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  175: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  177: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  180: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat > 0.195)) THEN 0],
#  185: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  187: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  197: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  200: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  202: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  203: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  205: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  208: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  209: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  211: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  212: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  213: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  215: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  219: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  220: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  221: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  222: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  227: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  228: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  229: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  231: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  237: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  238: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  239: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  240: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  242: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  251: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  261: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  262: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  263: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  264: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  270: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  274: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories > -0.018) AND (scaler__fat > -0.464) AND (scaler__fiber <= 1.225) AND (onehot__allergens_legumes <= 0.5) AND (onehot__meal_type_y_breakfast <= 0.5) AND (onehot__allergens_sesame <= 0.5) AND (scaler__fat > 3.082)) THEN 0],
#  276: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  277: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  278: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  285: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  294: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  295: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  298: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  303: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  305: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  307: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  308: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  311: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  317: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  322: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  325: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  326: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  328: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  330: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  331: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  332: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  336: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  337: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  341: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  342: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  345: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  348: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  357: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  359: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  363: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  364: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  366: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  371: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  372: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  381: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  383: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  388: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  393: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  399: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  407: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  408: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  415: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  419: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  424: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  428: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  429: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  430: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  433: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  440: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  446: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  447: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  448: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  450: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  456: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  461: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  463: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  464: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami > 0.5)) THEN 0],
#  465: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  466: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  467: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  474: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  481: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  486: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat > 0.195)) THEN 0],
#  489: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  490: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  492: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  493: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  498: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  501: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  516: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  518: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories > -0.018) AND (scaler__fat > -0.464) AND (scaler__fiber > 1.225)) THEN 0],
#  519: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  521: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  523: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  526: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  528: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  529: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  530: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  534: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  537: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  540: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  544: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  546: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  548: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami > 0.5)) THEN 0],
#  552: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  553: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  558: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  559: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  561: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  563: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  564: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  569: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  575: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  576: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  577: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  585: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  590: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  592: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  608: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  609: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  610: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  612: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  619: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  621: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  622: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  623: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  629: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  632: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  633: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  638: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  639: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  641: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  643: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  652: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  659: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  664: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten > 0.5)) THEN 0],
#  666: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  667: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates <= -0.773)) THEN 0],
#  669: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat > 0.5)) THEN 0],
#  670: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  672: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  673: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  677: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  683: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  684: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  689: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  691: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  697: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  701: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  702: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  707: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  709: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  713: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  715: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  717: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  719: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  722: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  723: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  725: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  726: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  733: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  735: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  738: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  741: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  743: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  747: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  753: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  757: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  760: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  762: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  775: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  776: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories > 0.647)) THEN 0],
#  778: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  781: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  782: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  783: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten > 0.5)) THEN 0],
#  784: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  786: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  788: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  789: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  795: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  796: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  799: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  804: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  807: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  811: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  814: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  816: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  820: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  821: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  825: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  826: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  828: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  832: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  840: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  841: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  849: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  851: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  863: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  870: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  873: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  874: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  875: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  876: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  877: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  878: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  893: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  895: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  896: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  902: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  909: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  910: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  911: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  913: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  915: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  916: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  921: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  923: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  926: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  928: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  929: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  930: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  932: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  933: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  937: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  938: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami > 0.5)) THEN 0],
#  942: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  943: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  945: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  949: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  952: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  953: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  954: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  958: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  961: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  963: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  964: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  966: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  967: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  978: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  982: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  984: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  985: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories > 0.647)) THEN 0],
#  986: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  987: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  988: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  989: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  991: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  997: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1000: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1004: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1011: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1017: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1019: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1026: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1033: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1035: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1044: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1046: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1047: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1053: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1054: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1055: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1063: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories > 0.647)) THEN 0],
#  1066: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1068: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1069: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1077: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1083: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1086: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1087: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1091: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  1092: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1097: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  1098: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1100: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1101: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1103: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1111: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1116: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1122: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1126: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1131: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1134: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1135: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1143: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1146: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1155: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1157: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1160: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1161: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1175: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1176: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1179: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1193: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1197: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1198: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1199: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1200: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1202: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1203: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1204: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1208: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1211: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1216: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1218: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1224: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1228: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1233: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1240: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1241: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1242: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1243: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1248: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1250: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1251: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1252: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1264: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1267: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1268: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1271: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories > 0.647)) THEN 0],
#  1272: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1286: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1290: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1291: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1292: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1296: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1303: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  1307: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1312: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1318: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat <= 0.195) AND (scaler__carbohydrates <= 0.912) AND (onehot__allergens_soy > 0.5)) THEN 0],
#  1320: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1323: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1325: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1328: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories > 0.647)) THEN 0],
#  1329: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1332: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1337: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1338: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1340: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1342: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1346: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  1349: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1352: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1357: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1359: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1361: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1372: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1374: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1382: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1388: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1391: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1392: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1393: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1395: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1399: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1406: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1407: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1408: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1413: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1415: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1417: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1419: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1421: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  1423: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1424: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1426: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1427: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1428: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1429: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1433: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1434: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1436: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1437: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1439: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1444: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1446: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1449: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1450: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1451: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories > -0.018) AND (scaler__fat > -0.464) AND (scaler__fiber <= 1.225) AND (onehot__allergens_legumes <= 0.5) AND (onehot__meal_type_y_breakfast <= 0.5) AND (onehot__allergens_sesame <= 0.5) AND (scaler__fat <= 3.082) AND (cluster > 1.5) AND (scaler__carbohydrates <= 2.143) AND (onehot__allergens_peanuts <= 0.5) AND (scaler__fat <= 0.284) AND (scaler__protein <= -0.615)) THEN 0],
#  1452: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  1453: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1455: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1465: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1467: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1469: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1472: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1473: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1478: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1488: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  1495: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1496: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1497: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1500: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1501: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1503: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1505: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1511: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1516: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1517: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1519: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1521: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1523: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1526: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1527: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1528: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  1530: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1532: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1542: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  1547: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1549: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1551: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1556: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1558: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1564: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1570: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1574: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1576: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1579: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1582: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1584: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1589: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1591: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1594: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1596: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1599: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1602: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1606: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1607: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1609: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1613: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1615: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1617: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1619: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1620: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1621: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1625: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  1630: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1631: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1639: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1640: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  1652: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1658: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein > 1.324)) THEN 0],
#  1659: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1660: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1661: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1664: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat > 0.5)) THEN 0],
#  1668: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1669: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1673: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1674: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1678: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1681: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat <= 0.195) AND (scaler__carbohydrates <= 0.912) AND (onehot__allergens_soy > 0.5)) THEN 0],
#  1682: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1687: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1689: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1691: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1695: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1697: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1704: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1705: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1706: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1709: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories > -0.018) AND (scaler__fat > -0.464) AND (scaler__fiber <= 1.225) AND (onehot__allergens_legumes <= 0.5) AND (onehot__meal_type_y_breakfast <= 0.5) AND (onehot__allergens_sesame <= 0.5) AND (scaler__fat <= 3.082) AND (cluster > 1.5) AND (scaler__carbohydrates <= 2.143) AND (onehot__allergens_peanuts <= 0.5) AND (scaler__fat <= 0.284) AND (scaler__protein > -0.615) AND (scaler__fiber > -0.919) AND (scaler__carbohydrates > -0.747) AND (scaler__fiber <= 0.346) AND (scaler__fat <= 0.13) AND (scaler__calories > 0.382)) THEN 0],
#  1710: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1711: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1714: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1716: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1721: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1723: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  1734: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1738: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1740: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1741: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1755: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1760: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1763: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1775: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1785: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1790: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  1792: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
# ...
#  2865: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2866: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2872: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2873: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2879: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2880: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2882: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories > 0.647)) THEN 0],
#  2883: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2884: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2885: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2891: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2896: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  2898: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2914: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2918: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2920: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  2922: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2925: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2926: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2928: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2930: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2932: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2934: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2937: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2939: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2944: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  2947: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2950: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2953: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2957: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  2959: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2960: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2961: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories > -0.018) AND (scaler__fat <= -0.464)) THEN 0],
#  2969: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2970: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2976: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2980: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2981: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2982: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2983: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2985: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  2986: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  2989: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3000: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  3005: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3006: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3007: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates <= -0.773)) THEN 0],
#  3011: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3016: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3018: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3020: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3023: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3030: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3035: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3038: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3040: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3041: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3042: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3047: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3049: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3061: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat <= 0.195) AND (scaler__carbohydrates > 0.912)) THEN 0],
#  3062: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3063: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat <= -0.791)) THEN 0],
#  3070: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3075: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories <= -0.018) AND (scaler__protein > -0.27) AND (scaler__fat <= 0.195) AND (scaler__carbohydrates <= 0.912) AND (onehot__allergens_soy > 0.5)) THEN 0],
#  3077: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3078: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3081: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3082: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3085: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  3092: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3097: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  3098: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3100: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten > 0.5)) THEN 0],
#  3104: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  3105: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  3111: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3115: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3120: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  3121: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat <= -0.791)) THEN 0],
#  3122: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3123: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3125: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3127: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3132: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  3133: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3134: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3138: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3141: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3150: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3159: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat > 0.5)) THEN 0],
#  3160: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein > 1.324)) THEN 0],
#  3166: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3174: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  3176: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3178: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3183: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3184: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3186: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3189: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  3194: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3201: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3204: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3206: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3207: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  3210: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  3211: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  3217: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3222: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3226: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3231: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3232: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3234: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3251: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3253: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3257: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3262: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates <= -0.773)) THEN 0],
#  3271: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3272: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3275: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3278: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  3279: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3283: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber > 2.193)) THEN 0],
#  3284: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3287: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3290: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3291: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3292: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3294: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3301: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3309: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3318: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3319: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3328: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3330: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3331: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3335: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation > 0.5)) THEN 0],
#  3344: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3351: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3353: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3356: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3357: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3361: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami <= 0.5) AND (scaler__carbohydrates > -0.773) AND (onehot__allergens_wheat <= 0.5) AND (scaler__fat > -0.791) AND (scaler__protein <= 1.324) AND (scaler__calories > -0.018) AND (scaler__fat > -0.464) AND (scaler__fiber <= 1.225) AND (onehot__allergens_legumes <= 0.5) AND (onehot__meal_type_y_breakfast <= 0.5) AND (onehot__allergens_sesame <= 0.5) AND (scaler__fat <= 3.082) AND (cluster > 1.5) AND (scaler__carbohydrates <= 2.143) AND (onehot__allergens_peanuts <= 0.5) AND (scaler__fat <= 0.284) AND (scaler__protein > -0.615) AND (scaler__fiber > -0.919) AND (scaler__carbohydrates > -0.747) AND (scaler__fiber <= 0.346) AND (scaler__fat <= 0.13) AND (scaler__calories <= 0.382) AND (onehot__meal_type_y_vegan > 0.5) AND (scaler__fiber <= -0.175) AND (scaler__carbohydrates <= -0.449)) THEN 0],
#  3364: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3365: [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour > 0.5)) THEN 0],
#  3367: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3371: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3372: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  3380: [IF ((onehot__cultural_restriction_vegan <= 0.5)) THEN 0],
#  ...}

# %%
dislike_dict_rules[464]
# Out:
# [IF ((onehot__cultural_restriction_vegan > 0.5) AND (onehot__meal_type_y_NotInformation <= 0.5) AND (onehot__taste_sour <= 0.5) AND (scaler__fiber <= 2.193) AND (scaler__calories <= 0.647) AND (onehot__allergens_gluten <= 0.5) AND (onehot__taste_umami > 0.5)) THEN 0]

# %%
selected_df.loc[data_indices[464], :]
# Out:
# day_number                                                                            134
# meal_type_x                                                                morning snacks
# userId                                                                            mr.a40e
# foodId                                                                          food_2144
# time_of_meal_consumption                                                          8.63876
# place_of_meal_consumption                                                            home
# social_situation_of_meal_consumption                                              friends
# appreciation_feedback                                                            0.492075
# nutrition_goal                                                               maintain_fit
# clinical_gender                                                                         M
# age_range                                                                           40-49
# life_style                                                                    Very active
# weight                                                                              68.04
# height                                                                                180
# projected_daily_calories                                                           3056.0
# current_daily_calories                                                             3056.0
# country_of_origin                                                                   Ghana
# living_country                                                                      China
# current_location                                                                    sd_PK
# cultural_factor                                                      vegetarian_observant
# probabilities                                                                         NaN
# allergy                                                                          Multiple
# Multi-allergy                                                        cow's milk tree nuts
# current_working_status                                                   Half-time-worker
# marital_status                                                                    Married
# ethnicity                                                                          Latino
# BMI                                                                               healthy
# next_BMI                                                                          healthy
# name                                                                  Vegan Pumpkin Curry
# raw_text                                74. Vegan Pumpkin Curry - 600 calories per por...
# cultural_restriction                                                                vegan
# calories                                                                            600.0
# allergens                                                                    NotAllergens
# recipeId                                                                        food_2144
# ingredients                             ingredients:\n- 1 small pumpkin, peeled and cu...
# instructions                            \n1. in a large skillet or pot, heat some oil ...
# carbohydrates                                                                        95.0
# fat                                                                                  48.0
# fiber                                                                                 4.6
# protein                                                                              16.3
# taste                                                                               umami
# cooking_style                                                                     sauteed
# meal_type_y                                                                        veggie
# prep_time                                                                            30.0
# cuisine                                                                            Indian
# price                                                                                 2.0
# ingredients_list                        pumpkin, onion, clove, garlic, minced, ginger,...
# y_pred                                                                                  0
# Name: 857910, dtype: object

# %%
from typing import List

# %%
from typing import List, Dict
import pandas as pd
import numpy as np
import bnlearn as bn

def create_hierarchical_edges(parents_list: List[str], child_node: str):
  list_of_edges = []
  for parent in parents_list:
    list_of_edges.append((parent, child_node))
  return list_of_edges


def create_bayesian_model_from_data(data_set: pd.DataFrame, wlist=None, edges=None):
    model = bn.structure_learning.fit(data_set, white_list=wlist, bw_list_method='nodes')
    if edges is not None:
      model['model'].add_edges_from(edges)
    model = bn.parameter_learning.fit(model, data_set)
    return model

# %%
def discretize_data(data: pd.DataFrame,
                    continuos_variables: List[str],
                    nbins: int = 10,
                    invert_order=True) -> Tuple[pd.DataFrame, Dict, Dict]:
  local_data = data.copy()
  discretize_transformer = {}
  dict_posible_values = {}
  for fac in continuos_variables:
    # discretizate
    array_values = data[fac].to_numpy()
    min = np.amin(array_values)
    max = np.amax(array_values)
    bins = np.linspace(min, max, num=nbins)
    discretize_transformer[fac] = bins
    discretized_data = np.digitize(array_values, bins, right=True)
    local_data[fac] = discretized_data
    # search for values
    dict_posible_values[fac] = sorted(np.unique(local_data[fac]))
  # return Bayesian network
  return local_data, discretize_transformer, dict_posible_values

# %%
discretized_df, discretize_dict, possible_vals = discretize_data(data=selected_df,
                    continuos_variables=numeric_features)

# %%
discretized_df['cluster'] = x_te_xai[:, -1]

# %%
factor_df = discretized_df.loc[:, categorical_features+numeric_features+['cluster', 'y_pred']]

# %%
factor_df.columns
# Out:
# Index(['BMI', 'age_range', 'allergens', 'allergy', 'clinical_gender',
#        'cultural_factor', 'cultural_restriction', 'current_working_status',
#        'ethnicity', 'life_style', 'marital_status', 'next_BMI',
#        'nutrition_goal', 'meal_type_y', 'taste', 'place_of_meal_consumption',
#        'social_situation_of_meal_consumption', 'calories', 'carbohydrates',
#        'current_daily_calories', 'fat', 'fiber', 'height', 'price',
#        'projected_daily_calories', 'protein', 'weight', 'day_number',
#        'time_of_meal_consumption', 'cluster', 'y_pred'],
#       dtype='object')

# %%
def generate_edges(causal_factors, effect):
  edges = []
  for cause in causal_factors:
    edges.append((cause, effect))
  return edges

def from_effect_to_cause(causal_factors, effect):
  edges = []
  for cause in causal_factors:
    edges.append((effect, cause))
  return edges

# %%
# list of edges
causes = ['BMI', 'age_range', 'allergens', 'allergy', 'clinical_gender',
       'cultural_factor', 'cultural_restriction','life_style', 'next_BMI',
       'nutrition_goal', 'meal_type_y', 'taste', 'time_of_meal_consumption',
       'place_of_meal_consumption', 'social_situation_of_meal_consumption',
       'calories', 'carbohydrates', 'current_daily_calories', 'fat', 'fiber',
       'height', 'price', 'projected_daily_calories', 'protein', 'weight',
       'day_number', 'cluster',]
effect='y_pred'
edges_list = generate_edges(causes, effect)

# %%
context_edges = from_effect_to_cause(['time_of_meal_consumption',
       'place_of_meal_consumption', 'social_situation_of_meal_consumption'], effect)

# %%
# load model

# %%
bn_control_model = bn.structure_learning.fit(factor_df, white_list=context_edges, bw_list_method='edges')
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Filter edges based on black_list/white_list
# [bnlearn] >Compute structure scores for model comparison (higher is better).

# %%
bn_control_model = bn.make_DAG(context_edges)
# Out:
# [bnlearn] >bayes DAG created.

# %%
bn_control_model = bn.parameter_learning.fit(bn_control_model, factor_df.copy())
# Out:
# [bnlearn] >Removing columns from dataframe to make consistent with DAG [['BMI' 'age_range' 'allergens' 'allergy' 'clinical_gender'
#  'cultural_factor' 'cultural_restriction' 'current_working_status'
#  'ethnicity' 'life_style' 'marital_status' 'next_BMI' 'nutrition_goal'
#  'meal_type_y' 'taste' 'calories' 'carbohydrates' 'current_daily_calories'
#  'fat' 'fiber' 'height' 'price' 'projected_daily_calories' 'protein'
#  'weight' 'day_number' 'cluster']]
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >CPD of y_pred:
# +-----------+----------+
# | y_pred(0) | 0.332187 |
# +-----------+----------+
# | y_pred(1) | 0.667813 |
# +-----------+----------+
# [bnlearn] >CPD of time_of_meal_consumption:
# +-----------------------------+----------------------+---------------------+
# | y_pred                      | y_pred(0)            | y_pred(1)           |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(0) | 0.02464268112370626  | 0.0125030644765874  |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(1) | 0.050763923114834894 | 0.03799950968374602 |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(2) | 0.15032035485460818  | 0.16401078695758764 |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(3) | 0.10645638245441104  | 0.09732777641578819 |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(4) | 0.08822079842286841  | 0.09634714390782055 |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(5) | 0.1779201577131592   | 0.18435891149791617 |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(6) | 0.10103499260719566  | 0.10566315273351312 |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(7) | 0.09117792015771316  | 0.08923755822505516 |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(8) | 0.15672745194677182  | 0.160333415052709   |
# +-----------------------------+----------------------+---------------------+
# | time_of_meal_consumption(9) | 0.0527353376047314   | 0.05221868104927679 |
# +-----------------------------+----------------------+---------------------+
# [bnlearn] >CPD of place_of_meal_consumption:
# +---------------------------------------+---------------------+--------------------+
# | y_pred                                | y_pred(0)           | y_pred(1)          |
# +---------------------------------------+---------------------+--------------------+
# | place_of_meal_consumption(home)       | 0.60850993921472    | 0.6660129116613549 |
# +---------------------------------------+---------------------+--------------------+
# | place_of_meal_consumption(outdoor)    | 0.15262033842615408 | 0.1271553485331372 |
# +---------------------------------------+---------------------+--------------------+
# | place_of_meal_consumption(restaurant) | 0.23886972235912599 | 0.2068317398055079 |
# +---------------------------------------+---------------------+--------------------+
# [bnlearn] >CPD of social_situation_of_meal_consumption:
# +--------------------------------------------------+---------------------+---------------------+
# | y_pred                                           | y_pred(0)           | y_pred(1)           |
# +--------------------------------------------------+---------------------+---------------------+
# | social_situation_of_meal_consumption(alone)      | 0.4346968950221784  | 0.4736455013483697  |
# +--------------------------------------------------+---------------------+---------------------+
# | social_situation_of_meal_consumption(colleagues) | 0.1429275505174963  | 0.11694042657514096 |
# +--------------------------------------------------+---------------------+---------------------+
# | social_situation_of_meal_consumption(family)     | 0.20946278955150321 | 0.2076489335621476  |
# +--------------------------------------------------+---------------------+---------------------+
# | social_situation_of_meal_consumption(friends)    | 0.21291276490882208 | 0.20176513851434175 |
# +--------------------------------------------------+---------------------+---------------------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).

# %%
bn_model = create_bayesian_model_from_data(factor_df)
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >Converting [<class 'pgmpy.base.DAG.DAG'>] to BayesianNetwork model.
# [bnlearn] >Converting adjmat to BayesianNetwork.
# [bnlearn] >CPD of BMI:
# +------------------+--------------------+-----+--------------------+---------------------+
# | height           | height(0)          | ... | height(9)          | height(9)           |
# +------------------+--------------------+-----+--------------------+---------------------+
# | weight           | weight(0)          | ... | weight(8)          | weight(9)           |
# +------------------+--------------------+-----+--------------------+---------------------+
# | BMI(healthy)     | 0.4094488188976378 | ... | 0.1453488372093023 | 0.09225092250922508 |
# +------------------+--------------------+-----+--------------------+---------------------+
# | BMI(obesity)     | 0.1968503937007874 | ... | 0.1453488372093023 | 0.7232472324723247  |
# +------------------+--------------------+-----+--------------------+---------------------+
# | BMI(overweight)  | 0.1968503937007874 | ... | 0.563953488372093  | 0.09225092250922508 |
# +------------------+--------------------+-----+--------------------+---------------------+
# | BMI(underweight) | 0.1968503937007874 | ... | 0.1453488372093023 | 0.09225092250922508 |
# +------------------+--------------------+-----+--------------------+---------------------+
# [bnlearn] >CPD of allergy:
# +---------------------+----------------------+-----+---------------------+---------------------+
# | BMI                 | BMI(healthy)         | ... | BMI(underweight)    | BMI(underweight)    |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | age_range           | age_range(18-29)     | ... | age_range(90-100)   | age_range(90-100)   |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | clinical_gender     | clinical_gender(F)   | ... | clinical_gender(F)  | clinical_gender(M)  |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | allergy(Multiple)   | 0.024905359633393107 | ... | 0.03453992815694944 | 0.2698412698412699  |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | allergy(NotAllergy) | 0.2926877864116358   | ... | 0.26664824537164966 | 0.05362505362505363 |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | allergy(cow's milk) | 0.024905359633393107 | ... | 0.2511743575573363  | 0.05362505362505363 |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | allergy(peanut)     | 0.14763897190675435  | ... | 0.1892788063000829  | 0.46203346203346213 |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | allergy(shellfish)  | 0.024905359633393107 | ... | 0.1892788063000829  | 0.05362505362505363 |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | allergy(soy)        | 0.315002988643156    | ... | 0.03453992815694944 | 0.05362505362505363 |
# +---------------------+----------------------+-----+---------------------+---------------------+
# | allergy(wheat)      | 0.16995417413827457  | ... | 0.03453992815694944 | 0.05362505362505363 |
# +---------------------+----------------------+-----+---------------------+---------------------+
# [bnlearn] >CPD of next_BMI:
# +-----------------------+---------------------+-----+----------------------+---------------------+
# | BMI                   | BMI(healthy)        | ... | BMI(overweight)      | BMI(underweight)    |
# +-----------------------+---------------------+-----+----------------------+---------------------+
# | next_BMI(healthy)     | 0.5875912408759124  | ... | 0.3136539287247746   | 0.4468503937007874  |
# +-----------------------+---------------------+-----+----------------------+---------------------+
# | next_BMI(obesity)     | 0.03509264458169568 | ... | 0.12215543151567196  | 0.08202099737532809 |
# +-----------------------+---------------------+-----+----------------------+---------------------+
# | next_BMI(overweight)  | 0.28607523862998313 | ... | 0.5373550880206097   | 0.08202099737532809 |
# +-----------------------+---------------------+-----+----------------------+---------------------+
# | next_BMI(underweight) | 0.09124087591240876 | ... | 0.026835551738943753 | 0.38910761154855644 |
# +-----------------------+---------------------+-----+----------------------+---------------------+
# [bnlearn] >CPD of nutrition_goal:
# +------------------------------+-----+----------------------+---------------------+
# | BMI                          | ... | BMI(overweight)      | BMI(underweight)    |
# +------------------------------+-----+----------------------+---------------------+
# | nutrition_goal(gain_weight)  | ... | 0.035780735651924994 | 0.7812773403324583  |
# +------------------------------+-----+----------------------+---------------------+
# | nutrition_goal(lose_weight)  | ... | 0.9284385286961498   | 0.10936132983377075 |
# +------------------------------+-----+----------------------+---------------------+
# | nutrition_goal(maintain_fit) | ... | 0.035780735651924994 | 0.10936132983377075 |
# +------------------------------+-----+----------------------+---------------------+
# [bnlearn] >CPD of projected_daily_calories:
# +-----------------------------+-----+----------------------+---------------------+
# | BMI                         | ... | BMI(underweight)     | BMI(underweight)    |
# +-----------------------------+-----+----------------------+---------------------+
# | height                      | ... | height(8)            | height(9)           |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(0) | ... | 0.044964028776978415 | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(1) | ... | 0.044964028776978415 | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(2) | ... | 0.044964028776978415 | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(3) | ... | 0.044964028776978415 | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(4) | ... | 0.48201438848920863  | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(5) | ... | 0.044964028776978415 | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(6) | ... | 0.044964028776978415 | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(7) | ... | 0.15827338129496404  | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(8) | ... | 0.044964028776978415 | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# | projected_daily_calories(9) | ... | 0.044964028776978415 | 0.09999999999999998 |
# +-----------------------------+-----+----------------------+---------------------+
# [bnlearn] >CPD of age_range:
# +------------------------+-----+---------------------------+
# | clinical_gender        | ... | clinical_gender(M)        |
# +------------------------+-----+---------------------------+
# | current_daily_calories | ... | current_daily_calories(9) |
# +------------------------+-----+---------------------------+
# | marital_status         | ... | marital_status(Single)    |
# +------------------------+-----+---------------------------+
# | age_range(18-29)       | ... | 0.125                     |
# +------------------------+-----+---------------------------+
# | age_range(30-39)       | ... | 0.125                     |
# +------------------------+-----+---------------------------+
# | age_range(40-49)       | ... | 0.125                     |
# +------------------------+-----+---------------------------+
# | age_range(50-59)       | ... | 0.125                     |
# +------------------------+-----+---------------------------+
# | age_range(60-69)       | ... | 0.125                     |
# +------------------------+-----+---------------------------+
# | age_range(70-79)       | ... | 0.125                     |
# +------------------------+-----+---------------------------+
# | age_range(80-89)       | ... | 0.125                     |
# +------------------------+-----+---------------------------+
# | age_range(90-100)      | ... | 0.125                     |
# +------------------------+-----+---------------------------+
# [bnlearn] >CPD of allergens:
# +-----------------------------------+------------+
# | allergens(Crustacean shellfish)   | 0.00325101 |
# +-----------------------------------+------------+
# | allergens(Dairy)                  | 0.00325101 |
# +-----------------------------------+------------+
# | allergens(Eggs)                   | 0.00341473 |
# +-----------------------------------+------------+
# | allergens(Fish)                   | 0.00357845 |
# +-----------------------------------+------------+
# | allergens(Milk)                   | 0.00423332 |
# +-----------------------------------+------------+
# | allergens(NotAllergens)           | 0.450533   |
# +-----------------------------------+------------+
# | allergens(Peanuts)                | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(Shellfish)              | 0.00325101 |
# +-----------------------------------+------------+
# | allergens(Soybeans)               | 0.00357845 |
# +-----------------------------------+------------+
# | allergens(Tree nuts)              | 0.00423332 |
# +-----------------------------------+------------+
# | allergens(corn)                   | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(dairy)                  | 0.0174946  |
# +-----------------------------------+------------+
# | allergens(dairy, eggs)            | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(dairy, gluten)          | 0.00947235 |
# +-----------------------------------+------------+
# | allergens(eggs)                   | 0.0119282  |
# +-----------------------------------+------------+
# | allergens(eggs, gluten)           | 0.00341473 |
# +-----------------------------------+------------+
# | allergens(garlic)                 | 0.00390588 |
# +-----------------------------------+------------+
# | allergens(gluten)                 | 0.0171672  |
# +-----------------------------------+------------+
# | allergens(lactose)                | 0.0264992  |
# +-----------------------------------+------------+
# | allergens(lactose, dairy)         | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(lactose, eggs)          | 0.00472448 |
# +-----------------------------------+------------+
# | allergens(lactose, tree nuts)     | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(legumes)                | 0.0328843  |
# +-----------------------------------+------------+
# | allergens(legumes, gluten)        | 0.00341473 |
# +-----------------------------------+------------+
# | allergens(meat)                   | 0.00325101 |
# +-----------------------------------+------------+
# | allergens(mustard)                | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(nightshade)             | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(peanuts)                | 0.00668912 |
# +-----------------------------------+------------+
# | allergens(peanuts, gluten)        | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(pork, soy, gluten)      | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(poultry)                | 0.00357845 |
# +-----------------------------------+------------+
# | allergens(rice, gluten)           | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(seafood)                | 0.00881748 |
# +-----------------------------------+------------+
# | allergens(seafood, dairy)         | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(seafood, lactose)       | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(seafood, soy)           | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(sesame)                 | 0.00685284 |
# +-----------------------------------+------------+
# | allergens(sesame, gluten)         | 0.00325101 |
# +-----------------------------------+------------+
# | allergens(sesame, soy)            | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(shellfish)              | 0.00718028 |
# +-----------------------------------+------------+
# | allergens(shellfish, dairy)       | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(shellfish, gluten)      | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(soy)                    | 0.0605529  |
# +-----------------------------------+------------+
# | allergens(soy, gluten)            | 0.00505192 |
# +-----------------------------------+------------+
# | allergens(soy, peanuts)           | 0.00325101 |
# +-----------------------------------+------------+
# | allergens(soy, shellfish, gluten) | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(soy, wheat)             | 0.00374216 |
# +-----------------------------------+------------+
# | allergens(soy, wheat, shellfish)  | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(spices)                 | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(tree nuts)              | 0.195622   |
# +-----------------------------------+------------+
# | allergens(tree nuts, dairy)       | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(tree nuts, gluten)      | 0.00341473 |
# +-----------------------------------+------------+
# | allergens(wheat)                  | 0.007344   |
# +-----------------------------------+------------+
# | allergens(wheat, dairy)           | 0.00325101 |
# +-----------------------------------+------------+
# | allergens(wheat, shellfish)       | 0.00308729 |
# +-----------------------------------+------------+
# | allergens(wheat, tree nuts)       | 0.00308729 |
# +-----------------------------------+------------+
# [bnlearn] >CPD of y_pred:
# +-----------+---------------------------------+-----+-----------------------------+
# | allergens | allergens(Crustacean shellfish) | ... | allergens(wheat, tree nuts) |
# +-----------+---------------------------------+-----+-----------------------------+
# | y_pred(0) | 0.5503597122302158              | ... | 0.5265151515151515          |
# +-----------+---------------------------------+-----+-----------------------------+
# | y_pred(1) | 0.44964028776978415             | ... | 0.4734848484848485          |
# +-----------+---------------------------------+-----+-----------------------------+
# [bnlearn] >CPD of clinical_gender:
# +------------------------+-----+------------------------------------+
# | current_working_status | ... | current_working_status(Unemployed) |
# +------------------------+-----+------------------------------------+
# | height                 | ... | height(9)                          |
# +------------------------+-----+------------------------------------+
# | clinical_gender(F)     | ... | 0.2969121140142518                 |
# +------------------------+-----+------------------------------------+
# | clinical_gender(M)     | ... | 0.7030878859857482                 |
# +------------------------+-----+------------------------------------+
# [bnlearn] >CPD of life_style:
# +-------------------------------+-----+------------------------------+
# | clinical_gender               | ... | clinical_gender(M)           |
# +-------------------------------+-----+------------------------------+
# | nutrition_goal                | ... | nutrition_goal(maintain_fit) |
# +-------------------------------+-----+------------------------------+
# | projected_daily_calories      | ... | projected_daily_calories(9)  |
# +-------------------------------+-----+------------------------------+
# | life_style(Lightly active)    | ... | 0.25                         |
# +-------------------------------+-----+------------------------------+
# | life_style(Moderately active) | ... | 0.25                         |
# +-------------------------------+-----+------------------------------+
# | life_style(Sedentary)         | ... | 0.25                         |
# +-------------------------------+-----+------------------------------+
# | life_style(Very active)       | ... | 0.25                         |
# +-------------------------------+-----+------------------------------+
# [bnlearn] >CPD of marital_status:
# +-------------------------+-----+------------------------------------+
# | clinical_gender         | ... | clinical_gender(M)                 |
# +-------------------------+-----+------------------------------------+
# | current_daily_calories  | ... | current_daily_calories(9)          |
# +-------------------------+-----+------------------------------------+
# | current_working_status  | ... | current_working_status(Unemployed) |
# +-------------------------+-----+------------------------------------+
# | marital_status(Married) | ... | 0.6951219512195121                 |
# +-------------------------+-----+------------------------------------+
# | marital_status(Single)  | ... | 0.3048780487804878                 |
# +-------------------------+-----+------------------------------------+
# [bnlearn] >CPD of current_working_status:
# +------------------------------------------+----------+
# | current_working_status(Full-time-worker) | 0.264407 |
# +------------------------------------------+----------+
# | current_working_status(Half-time-worker) | 0.24296  |
# +------------------------------------------+----------+
# | current_working_status(Self-employee)    | 0.22053  |
# +------------------------------------------+----------+
# | current_working_status(Unemployed)       | 0.272102 |
# +------------------------------------------+----------+
# [bnlearn] >CPD of ethnicity:
# +------------------------+-----+------------------------------------+
# | current_working_status | ... | current_working_status(Unemployed) |
# +------------------------+-----+------------------------------------+
# | ethnicity(Asian)       | ... | 0.3071600481347774                 |
# +------------------------+-----+------------------------------------+
# | ethnicity(Black)       | ... | 0.22713598074608904                |
# +------------------------+-----+------------------------------------+
# | ethnicity(Latino)      | ... | 0.2584235860409146                 |
# +------------------------+-----+------------------------------------+
# | ethnicity(White)       | ... | 0.20728038507821903                |
# +------------------------+-----+------------------------------------+
# [bnlearn] >CPD of height:
# +------------------------+-----+------------------------------------+
# | current_working_status | ... | current_working_status(Unemployed) |
# +------------------------+-----+------------------------------------+
# | ethnicity              | ... | ethnicity(White)                   |
# +------------------------+-----+------------------------------------+
# | height(0)              | ... | 0.02015803902596355                |
# +------------------------+-----+------------------------------------+
# | height(2)              | ... | 0.04918561522335106                |
# +------------------------+-----+------------------------------------+
# | height(3)              | ... | 0.10433800999838734                |
# +------------------------+-----+------------------------------------+
# | height(4)              | ... | 0.2320593452668924                 |
# +------------------------+-----+------------------------------------+
# | height(5)              | ... | 0.2262538300274149                 |
# +------------------------+-----+------------------------------------+
# | height(6)              | ... | 0.10433800999838734                |
# +------------------------+-----+------------------------------------+
# | height(7)              | ... | 0.1478793742944686                 |
# +------------------------+-----+------------------------------------+
# | height(8)              | ... | 0.06369940332204482                |
# +------------------------+-----+------------------------------------+
# | height(9)              | ... | 0.052088372843089814               |
# +------------------------+-----+------------------------------------+
# [bnlearn] >CPD of cultural_factor:
# +---------------------------------------+-----+-------------------------+
# | height                                | ... | height(9)               |
# +---------------------------------------+-----+-------------------------+
# | life_style                            | ... | life_style(Very active) |
# +---------------------------------------+-----+-------------------------+
# | cultural_factor(NotRestriction)       | ... | 0.12939958592132506     |
# +---------------------------------------+-----+-------------------------+
# | cultural_factor(flexi_observant)      | ... | 0.12939958592132506     |
# +---------------------------------------+-----+-------------------------+
# | cultural_factor(halal_observant)      | ... | 0.3530020703933747      |
# +---------------------------------------+-----+-------------------------+
# | cultural_factor(kosher_observant)     | ... | 0.12939958592132506     |
# +---------------------------------------+-----+-------------------------+
# | cultural_factor(vegan_observant)      | ... | 0.12939958592132506     |
# +---------------------------------------+-----+-------------------------+
# | cultural_factor(vegetarian_observant) | ... | 0.12939958592132506     |
# +---------------------------------------+-----+-------------------------+
# [bnlearn] >CPD of current_daily_calories:
# +---------------------------+-----+------------------------------+
# | nutrition_goal            | ... | nutrition_goal(maintain_fit) |
# +---------------------------+-----+------------------------------+
# | projected_daily_calories  | ... | projected_daily_calories(9)  |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(0) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(1) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(2) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(3) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(4) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(5) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(6) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(7) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(8) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# | current_daily_calories(9) | ... | 0.10000000000000002          |
# +---------------------------+-----+------------------------------+
# [bnlearn] >CPD of taste:
# +---------------------+----------------------+----------------------+
# | y_pred              | y_pred(0)            | y_pred(1)            |
# +---------------------+----------------------+----------------------+
# | taste(bitter)       | 0.037703302119270574 | 0.058960529541554306 |
# +---------------------+----------------------+----------------------+
# | taste(salty)        | 0.4768358797437161   | 0.4524393233635695   |
# +---------------------+----------------------+----------------------+
# | taste(sour)         | 0.1402168555938886   | 0.015322382936994361 |
# +---------------------+----------------------+----------------------+
# | taste(sour, salty)  | 0.03178905864958107  | 0.015322382936994361 |
# +---------------------+----------------------+----------------------+
# | taste(sweet)        | 0.1924593395761459   | 0.41174307428291246  |
# +---------------------+----------------------+----------------------+
# | taste(sweet, umami) | 0.03129620502710695  | 0.015322382936994361 |
# +---------------------+----------------------+----------------------+
# | taste(umami)        | 0.05101034992607196  | 0.015322382936994361 |
# +---------------------+----------------------+----------------------+
# | taste(umami, salty) | 0.038689009364218825 | 0.015567541063986272 |
# +---------------------+----------------------+----------------------+
# [bnlearn] >CPD of carbohydrates:
# +------------------+----------------------+-----+---------------------+---------------------+
# | taste            | taste(bitter)        | ... | taste(umami)        | taste(umami, salty) |
# +------------------+----------------------+-----+---------------------+---------------------+
# | carbohydrates(0) | 0.056331680937359185 | ... | 0.10757314974182443 | 0.1398390342052314  |
# +------------------+----------------------+-----+---------------------+---------------------+
# | carbohydrates(1) | 0.6557007661108609   | ... | 0.34853700516351116 | 0.21730382293762576 |
# +------------------+----------------------+-----+---------------------+---------------------+
# | carbohydrates(2) | 0.05948625506985129  | ... | 0.11359724612736659 | 0.13279678068410464 |
# +------------------+----------------------+-----+---------------------+---------------------+
# | carbohydrates(3) | 0.05948625506985129  | ... | 0.10757314974182443 | 0.12575452716297786 |
# +------------------+----------------------+-----+---------------------+---------------------+
# | carbohydrates(4) | 0.056331680937359185 | ... | 0.10757314974182443 | 0.12575452716297786 |
# +------------------+----------------------+-----+---------------------+---------------------+
# | carbohydrates(5) | 0.056331680937359185 | ... | 0.10757314974182443 | 0.13279678068410464 |
# +------------------+----------------------+-----+---------------------+---------------------+
# | carbohydrates(9) | 0.056331680937359185 | ... | 0.10757314974182443 | 0.12575452716297786 |
# +------------------+----------------------+-----+---------------------+---------------------+
# [bnlearn] >CPD of price:
# +---------------+---------------------+-----+--------------------+---------------------+
# | carbohydrates | carbohydrates(0)    | ... | carbohydrates(5)   | carbohydrates(9)    |
# +---------------+---------------------+-----+--------------------+---------------------+
# | price(0)      | 0.25                | ... | 0.2465483234714004 | 0.24826216484607747 |
# +---------------+---------------------+-----+--------------------+---------------------+
# | price(5)      | 0.2765151515151515  | ... | 0.2534516765285996 | 0.25521350546176763 |
# +---------------+---------------------+-----+--------------------+---------------------+
# | price(7)      | 0.23674242424242425 | ... | 0.2465483234714004 | 0.24826216484607747 |
# +---------------+---------------------+-----+--------------------+---------------------+
# | price(9)      | 0.23674242424242425 | ... | 0.2534516765285996 | 0.24826216484607747 |
# +---------------+---------------------+-----+--------------------+---------------------+
# [bnlearn] >CPD of weight:
# +-----------+---------------------+-----+---------------------+---------------------+
# | height    | height(0)           | ... | height(8)           | height(9)           |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(0) | 0.12366114897760465 | ... | 0.02485089463220676 | 0.08045052292839903 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(1) | 0.09737098344693279 | ... | 0.02485089463220676 | 0.08045052292839903 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(2) | 0.09737098344693279 | ... | 0.02485089463220676 | 0.08045052292839903 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(3) | 0.09737098344693279 | ... | 0.10089463220675945 | 0.08045052292839903 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(4) | 0.09737098344693279 | ... | 0.30442345924453285 | 0.08045052292839903 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(5) | 0.09737098344693279 | ... | 0.06510934393638171 | 0.08045052292839903 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(6) | 0.09737098344693279 | ... | 0.08971172962226641 | 0.08045052292839903 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(7) | 0.09737098344693279 | ... | 0.22614314115308154 | 0.08045052292839903 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(8) | 0.09737098344693279 | ... | 0.11431411530815111 | 0.13837489943684633 |
# +-----------+---------------------+-----+---------------------+---------------------+
# | weight(9) | 0.09737098344693279 | ... | 0.02485089463220676 | 0.2180209171359614  |
# +-----------+---------------------+-----+---------------------+---------------------+
# [bnlearn] >CPD of protein:
# +------------+----------------------+----------------------+
# | y_pred     | y_pred(0)            | y_pred(1)            |
# +------------+----------------------+----------------------+
# | protein(0) | 0.04068780461091943  | 0.06216120508839311  |
# +------------+----------------------+----------------------+
# | protein(1) | 0.6700618805103771   | 0.8424995233036418   |
# +------------+----------------------+----------------------+
# | protein(2) | 0.10180165379771092  | 0.013619895943994985 |
# +------------+----------------------+----------------------+
# | protein(3) | 0.041180658233393556 | 0.013619895943994985 |
# +------------+----------------------+----------------------+
# | protein(4) | 0.03181643940638518  | 0.013619895943994985 |
# +------------+----------------------+----------------------+
# | protein(5) | 0.02885931767154043  | 0.013619895943994985 |
# +------------+----------------------+----------------------+
# | protein(6) | 0.029352171294014556 | 0.013619895943994985 |
# +------------+----------------------+----------------------+
# | protein(8) | 0.028366464049066304 | 0.013619895943994985 |
# +------------+----------------------+----------------------+
# | protein(9) | 0.02787361042659218  | 0.013619895943994985 |
# +------------+----------------------+----------------------+
# [bnlearn] >CPD of fiber:
# +----------+----------------------+-----+---------------------+---------------------+
# | protein  | protein(0)           | ... | protein(8)          | protein(9)          |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(0) | 0.6161983471074383   | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(1) | 0.09256198347107442  | ... | 0.11591355599214143 | 0.10802775024777005 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(2) | 0.05090909090909093  | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(3) | 0.03900826446280993  | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(4) | 0.03603305785123968  | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(5) | 0.033057851239669436 | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(6) | 0.033057851239669436 | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(7) | 0.033057851239669436 | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(8) | 0.033057851239669436 | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# | fiber(9) | 0.033057851239669436 | ... | 0.09823182711198426 | 0.09910802775024775 |
# +----------+----------------------+-----+---------------------+---------------------+
# [bnlearn] >CPD of cultural_restriction:
# +--------------------------------------+----------------------+----------------------+
# | y_pred                               | y_pred(0)            | y_pred(1)            |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(NotRestriction) | 0.04862822408411367  | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(alcohol-based)  | 0.021521274848036794 | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(dairy)          | 0.021028421225562668 | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(dessert)        | 0.023492689337933293 | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(grain-based)    | 0.02595695745030392  | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(halal)          | 0.1861343847543946   | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(kosher)         | 0.1964843108263512   | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(meat-based)     | 0.08707080663709542  | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(pescatarian)    | 0.023492689337933293 | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(seafood-based)  | 0.022999835715459167 | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(vegan)          | 0.1260062428125513   | 0.8876358584620414   |
# +--------------------------------------+----------------------+----------------------+
# | cultural_restriction(vegetarian)     | 0.21718416297026447  | 0.010214921957996241 |
# +--------------------------------------+----------------------+----------------------+
# [bnlearn] >CPD of meal_type_y:
# +-----+-----------------------+
# | ... | y_pred(1)             |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.040564522325855404  |
# +-----+-----------------------+
# | ... | 0.09155741274017264   |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.002074696388125565  |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.006487542673979941  |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# | ... | 0.3146513083028105    |
# +-----+-----------------------+
# | ... | 0.21266552747417605   |
# +-----+-----------------------+
# | ... | 0.22222669442686055   |
# +-----+-----------------------+
# | ... | 0.0018295382611336552 |
# +-----+-----------------------+
# [bnlearn] >CPD of calories:
# +-------------+----------------------+----------------------+
# | y_pred      | y_pred(0)            | y_pred(1)            |
# +-------------+----------------------+----------------------+
# | calories(0) | 0.02787361042659218  | 0.013619895943994985 |
# +-------------+----------------------+----------------------+
# | calories(1) | 0.6971688297464539   | 0.8910408324480399   |
# +-------------+----------------------+----------------------+
# | calories(2) | 0.08356606976616829  | 0.013619895943994985 |
# +-------------+----------------------+----------------------+
# | calories(3) | 0.044137779968238304 | 0.013619895943994985 |
# +-------------+----------------------+----------------------+
# | calories(4) | 0.03378785389628168  | 0.013619895943994985 |
# +-------------+----------------------+----------------------+
# | calories(5) | 0.029352171294014556 | 0.013619895943994985 |
# +-------------+----------------------+----------------------+
# | calories(6) | 0.02787361042659218  | 0.013619895943994985 |
# +-------------+----------------------+----------------------+
# | calories(7) | 0.028366464049066304 | 0.013619895943994985 |
# +-------------+----------------------+----------------------+
# | calories(9) | 0.02787361042659218  | 0.013619895943994985 |
# +-------------+----------------------+----------------------+
# [bnlearn] >CPD of fat:
# +--------+----------------------+---------------------+
# | y_pred | y_pred(0)            | y_pred(1)           |
# +--------+----------------------+---------------------+
# | fat(0) | 0.044568049003731625 | 0.01751129478513641 |
# +--------+----------------------+---------------------+
# | fat(1) | 0.7508272900091532   | 0.8949322312891813  |
# +--------+----------------------+---------------------+
# | fat(2) | 0.05688938956558476  | 0.01751129478513641 |
# +--------+----------------------+---------------------+
# | fat(3) | 0.037668098289093864 | 0.01751129478513641 |
# +--------+----------------------+---------------------+
# | fat(4) | 0.03717524466661974  | 0.01751129478513641 |
# +--------+----------------------+---------------------+
# | fat(5) | 0.03668239104414562  | 0.01751129478513641 |
# +--------+----------------------+---------------------+
# | fat(9) | 0.03618953742167149  | 0.01751129478513641 |
# +--------+----------------------+---------------------+
# [bnlearn] >CPD of cluster:
# +--------------+---------------------+---------------------+
# | y_pred       | y_pred(0)           | y_pred(1)           |
# +--------------+---------------------+---------------------+
# | cluster(0.0) | 0.1703630688352226  | 0.04085968783198496 |
# +--------------+---------------------+---------------------+
# | cluster(2.0) | 0.08509939214719894 | 0.04085968783198496 |
# +--------------+---------------------+---------------------+
# | cluster(3.0) | 0.7445375390175785  | 0.9182806243360301  |
# +--------------+---------------------+---------------------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >WARNING> Skipping computing structure score for [k2].

# %%
evidence_like = factor_df.loc[data_indices[4], :].to_dict()
evidence_dislike = factor_df.loc[data_indices[464], :].to_dict()

# %%
def print_CPDS(causes, evidence_dict, model):
  nodes_to_exclude = []
  for cause in causes:
    if cause not in model['model'] and cause in evidence_dict.keys():
      del evidence_dict[cause]
    nodes_to_exclude.append(cause)
  print(f"Excluded nodes: {nodes_to_exclude}")
  for cause in evidence_dict.keys():
    print(f"Cause: {cause}:")
    if cause in evidence_dict.keys():
      tem_evident_dict = evidence_dict.copy()
      del tem_evident_dict[cause]
      cpd = bn.inference.fit(model, variables=[cause], evidence=tem_evident_dict)
      print(cpd)
    print("------------------------------------------")

# %%
print_CPDS(causes, evidence_like, bn_model)
# Out:
# Excluded nodes: ['BMI', 'age_range', 'allergens', 'allergy', 'clinical_gender', 'cultural_factor', 'cultural_restriction', 'life_style', 'next_BMI', 'nutrition_goal', 'meal_type_y', 'taste', 'time_of_meal_consumption', 'place_of_meal_consumption', 'social_situation_of_meal_consumption', 'calories', 'carbohydrates', 'current_daily_calories', 'fat', 'fiber', 'height', 'price', 'projected_daily_calories', 'protein', 'weight', 'day_number', 'cluster']
# Cause: BMI:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-------------+-------------+
# |    | BMI         |           p |
# +====+=============+=============+
# |  0 | healthy     | 0.999268    |
# +----+-------------+-------------+
# |  1 | obesity     | 0.000479291 |
# +----+-------------+-------------+
# |  2 | overweight  | 0.000142167 |
# +----+-------------+-------------+
# |  3 | underweight | 0.000110284 |
# +----+-------------+-------------+
# +------------------+------------+
# | BMI              |   phi(BMI) |
# +==================+============+
# | BMI(healthy)     |     0.9993 |
# +------------------+------------+
# | BMI(obesity)     |     0.0005 |
# +------------------+------------+
# | BMI(overweight)  |     0.0001 |
# +------------------+------------+
# | BMI(underweight) |     0.0001 |
# +------------------+------------+
# ------------------------------------------
# Cause: age_range:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-------------+------------+
# |    | age_range   |          p |
# +====+=============+============+
# |  0 | 18-29       | 0.0775511  |
# +----+-------------+------------+
# |  1 | 30-39       | 0.0658166  |
# +----+-------------+------------+
# |  2 | 40-49       | 0.0887994  |
# +----+-------------+------------+
# |  3 | 50-59       | 0.61164    |
# +----+-------------+------------+
# |  4 | 60-69       | 0.130688   |
# +----+-------------+------------+
# |  5 | 70-79       | 0.0112071  |
# +----+-------------+------------+
# |  6 | 80-89       | 0.0129061  |
# +----+-------------+------------+
# |  7 | 90-100      | 0.00139193 |
# +----+-------------+------------+
# +-------------------+------------------+
# | age_range         |   phi(age_range) |
# +===================+==================+
# | age_range(18-29)  |           0.0776 |
# +-------------------+------------------+
# | age_range(30-39)  |           0.0658 |
# +-------------------+------------------+
# | age_range(40-49)  |           0.0888 |
# +-------------------+------------------+
# | age_range(50-59)  |           0.6116 |
# +-------------------+------------------+
# | age_range(60-69)  |           0.1307 |
# +-------------------+------------------+
# | age_range(70-79)  |           0.0112 |
# +-------------------+------------------+
# | age_range(80-89)  |           0.0129 |
# +-------------------+------------------+
# | age_range(90-100) |           0.0014 |
# +-------------------+------------------+
# ------------------------------------------
# Cause: allergens:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+------------------------+------------+
# |    | allergens              |          p |
# +====+========================+============+
# |  0 | Crustacean shellfish   | 0.00218891 |
# +----+------------------------+------------+
# |  1 | Dairy                  | 0.00218891 |
# +----+------------------------+------------+
# |  2 | Eggs                   | 0.00218891 |
# +----+------------------------+------------+
# |  3 | Fish                   | 0.00218891 |
# +----+------------------------+------------+
# |  4 | Milk                   | 0.00218891 |
# +----+------------------------+------------+
# |  5 | NotAllergens           | 0.49275    |
# +----+------------------------+------------+
# |  6 | Peanuts                | 0.00218891 |
# +----+------------------------+------------+
# |  7 | Shellfish              | 0.00218891 |
# +----+------------------------+------------+
# |  8 | Soybeans               | 0.00218891 |
# +----+------------------------+------------+
# |  9 | Tree nuts              | 0.00218891 |
# +----+------------------------+------------+
# | 10 | corn                   | 0.00218891 |
# +----+------------------------+------------+
# | 11 | dairy                  | 0.00218891 |
# +----+------------------------+------------+
# | 12 | dairy, eggs            | 0.00218891 |
# +----+------------------------+------------+
# | 13 | dairy, gluten          | 0.00218891 |
# +----+------------------------+------------+
# | 14 | eggs                   | 0.00218891 |
# +----+------------------------+------------+
# | 15 | eggs, gluten           | 0.00218891 |
# +----+------------------------+------------+
# | 16 | garlic                 | 0.00218891 |
# +----+------------------------+------------+
# | 17 | gluten                 | 0.00218891 |
# +----+------------------------+------------+
# | 18 | lactose                | 0.00243407 |
# +----+------------------------+------------+
# | 19 | lactose, dairy         | 0.00218891 |
# +----+------------------------+------------+
# | 20 | lactose, eggs          | 0.00218891 |
# +----+------------------------+------------+
# | 21 | lactose, tree nuts     | 0.00243407 |
# +----+------------------------+------------+
# | 22 | legumes                | 0.0450916  |
# +----+------------------------+------------+
# | 23 | legumes, gluten        | 0.00218891 |
# +----+------------------------+------------+
# | 24 | meat                   | 0.00218891 |
# +----+------------------------+------------+
# | 25 | mustard                | 0.00243407 |
# +----+------------------------+------------+
# | 26 | nightshade             | 0.00218891 |
# +----+------------------------+------------+
# | 27 | peanuts                | 0.00218891 |
# +----+------------------------+------------+
# | 28 | peanuts, gluten        | 0.00218891 |
# +----+------------------------+------------+
# | 29 | pork, soy, gluten      | 0.00218891 |
# +----+------------------------+------------+
# | 30 | poultry                | 0.00218891 |
# +----+------------------------+------------+
# | 31 | rice, gluten           | 0.00218891 |
# +----+------------------------+------------+
# | 32 | seafood                | 0.00218891 |
# +----+------------------------+------------+
# | 33 | seafood, dairy         | 0.00218891 |
# +----+------------------------+------------+
# | 34 | seafood, lactose       | 0.00218891 |
# +----+------------------------+------------+
# | 35 | seafood, soy           | 0.00218891 |
# +----+------------------------+------------+
# | 36 | sesame                 | 0.00218891 |
# +----+------------------------+------------+
# | 37 | sesame, gluten         | 0.00218891 |
# +----+------------------------+------------+
# | 38 | sesame, soy            | 0.00218891 |
# +----+------------------------+------------+
# | 39 | shellfish              | 0.00218891 |
# +----+------------------------+------------+
# | 40 | shellfish, dairy       | 0.00218891 |
# +----+------------------------+------------+
# | 41 | shellfish, gluten      | 0.00218891 |
# +----+------------------------+------------+
# | 42 | soy                    | 0.0774525  |
# +----+------------------------+------------+
# | 43 | soy, gluten            | 0.00218891 |
# +----+------------------------+------------+
# | 44 | soy, peanuts           | 0.00218891 |
# +----+------------------------+------------+
# | 45 | soy, shellfish, gluten | 0.00218891 |
# +----+------------------------+------------+
# | 46 | soy, wheat             | 0.00218891 |
# +----+------------------------+------------+
# | 47 | soy, wheat, shellfish  | 0.00218891 |
# +----+------------------------+------------+
# | 48 | spices                 | 0.00218891 |
# +----+------------------------+------------+
# | 49 | tree nuts              | 0.269656   |
# +----+------------------------+------------+
# | 50 | tree nuts, dairy       | 0.00218891 |
# +----+------------------------+------------+
# | 51 | tree nuts, gluten      | 0.00267923 |
# +----+------------------------+------------+
# | 52 | wheat                  | 0.00218891 |
# +----+------------------------+------------+
# | 53 | wheat, dairy           | 0.00218891 |
# +----+------------------------+------------+
# | 54 | wheat, shellfish       | 0.00218891 |
# +----+------------------------+------------+
# | 55 | wheat, tree nuts       | 0.00218891 |
# +----+------------------------+------------+
# +-----------------------------------+------------------+
# | allergens                         |   phi(allergens) |
# +===================================+==================+
# | allergens(Crustacean shellfish)   |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(Dairy)                  |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(Eggs)                   |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(Fish)                   |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(Milk)                   |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(NotAllergens)           |           0.4928 |
# +-----------------------------------+------------------+
# | allergens(Peanuts)                |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(Shellfish)              |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(Soybeans)               |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(Tree nuts)              |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(corn)                   |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(dairy)                  |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(dairy, eggs)            |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(dairy, gluten)          |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(eggs)                   |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(eggs, gluten)           |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(garlic)                 |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(gluten)                 |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(lactose)                |           0.0024 |
# +-----------------------------------+------------------+
# | allergens(lactose, dairy)         |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(lactose, eggs)          |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(lactose, tree nuts)     |           0.0024 |
# +-----------------------------------+------------------+
# | allergens(legumes)                |           0.0451 |
# +-----------------------------------+------------------+
# | allergens(legumes, gluten)        |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(meat)                   |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(mustard)                |           0.0024 |
# +-----------------------------------+------------------+
# | allergens(nightshade)             |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(peanuts)                |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(peanuts, gluten)        |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(pork, soy, gluten)      |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(poultry)                |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(rice, gluten)           |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(seafood)                |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(seafood, dairy)         |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(seafood, lactose)       |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(seafood, soy)           |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(sesame)                 |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(sesame, gluten)         |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(sesame, soy)            |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(shellfish)              |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(shellfish, dairy)       |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(shellfish, gluten)      |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(soy)                    |           0.0775 |
# +-----------------------------------+------------------+
# | allergens(soy, gluten)            |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(soy, peanuts)           |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(soy, shellfish, gluten) |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(soy, wheat)             |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(soy, wheat, shellfish)  |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(spices)                 |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(tree nuts)              |           0.2697 |
# +-----------------------------------+------------------+
# | allergens(tree nuts, dairy)       |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(tree nuts, gluten)      |           0.0027 |
# +-----------------------------------+------------------+
# | allergens(wheat)                  |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(wheat, dairy)           |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(wheat, shellfish)       |           0.0022 |
# +-----------------------------------+------------------+
# | allergens(wheat, tree nuts)       |           0.0022 |
# +-----------------------------------+------------------+
# ------------------------------------------
# Cause: allergy:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+------------+-----------+
# |    | allergy    |         p |
# +====+============+===========+
# |  0 | Multiple   | 0.113104  |
# +----+------------+-----------+
# |  1 | NotAllergy | 0.17436   |
# +----+------------+-----------+
# |  2 | cow's milk | 0.0273463 |
# +----+------------+-----------+
# |  3 | peanut     | 0.0273463 |
# +----+------------+-----------+
# |  4 | shellfish  | 0.0273463 |
# +----+------------+-----------+
# |  5 | soy        | 0.149858  |
# +----+------------+-----------+
# |  6 | wheat      | 0.480639  |
# +----+------------+-----------+
# +---------------------+----------------+
# | allergy             |   phi(allergy) |
# +=====================+================+
# | allergy(Multiple)   |         0.1131 |
# +---------------------+----------------+
# | allergy(NotAllergy) |         0.1744 |
# +---------------------+----------------+
# | allergy(cow's milk) |         0.0273 |
# +---------------------+----------------+
# | allergy(peanut)     |         0.0273 |
# +---------------------+----------------+
# | allergy(shellfish)  |         0.0273 |
# +---------------------+----------------+
# | allergy(soy)        |         0.1499 |
# +---------------------+----------------+
# | allergy(wheat)      |         0.4806 |
# +---------------------+----------------+
# ------------------------------------------
# Cause: clinical_gender:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-------------------+-----------+
# |    | clinical_gender   |         p |
# +====+===================+===========+
# |  0 | F                 | 0.905408  |
# +----+-------------------+-----------+
# |  1 | M                 | 0.0945917 |
# +----+-------------------+-----------+
# +--------------------+------------------------+
# | clinical_gender    |   phi(clinical_gender) |
# +====================+========================+
# | clinical_gender(F) |                 0.9054 |
# +--------------------+------------------------+
# | clinical_gender(M) |                 0.0946 |
# +--------------------+------------------------+
# ------------------------------------------
# Cause: cultural_factor:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+----------------------+-----------+
# |    | cultural_factor      |         p |
# +====+======================+===========+
# |  0 | NotRestriction       | 0.404203  |
# +----+----------------------+-----------+
# |  1 | flexi_observant      | 0.259042  |
# +----+----------------------+-----------+
# |  2 | halal_observant      | 0.0610948 |
# +----+----------------------+-----------+
# |  3 | kosher_observant     | 0.0610948 |
# +----+----------------------+-----------+
# |  4 | vegan_observant      | 0.15347   |
# +----+----------------------+-----------+
# |  5 | vegetarian_observant | 0.0610948 |
# +----+----------------------+-----------+
# +---------------------------------------+------------------------+
# | cultural_factor                       |   phi(cultural_factor) |
# +=======================================+========================+
# | cultural_factor(NotRestriction)       |                 0.4042 |
# +---------------------------------------+------------------------+
# | cultural_factor(flexi_observant)      |                 0.2590 |
# +---------------------------------------+------------------------+
# | cultural_factor(halal_observant)      |                 0.0611 |
# +---------------------------------------+------------------------+
# | cultural_factor(kosher_observant)     |                 0.0611 |
# +---------------------------------------+------------------------+
# | cultural_factor(vegan_observant)      |                 0.1535 |
# +---------------------------------------+------------------------+
# | cultural_factor(vegetarian_observant) |                 0.0611 |
# +---------------------------------------+------------------------+
# ------------------------------------------
# Cause: cultural_restriction:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+------------------------+-----------+
# |    | cultural_restriction   |         p |
# +====+========================+===========+
# |  0 | NotRestriction         | 0.0102149 |
# +----+------------------------+-----------+
# |  1 | alcohol-based          | 0.0102149 |
# +----+------------------------+-----------+
# |  2 | dairy                  | 0.0102149 |
# +----+------------------------+-----------+
# |  3 | dessert                | 0.0102149 |
# +----+------------------------+-----------+
# |  4 | grain-based            | 0.0102149 |
# +----+------------------------+-----------+
# |  5 | halal                  | 0.0102149 |
# +----+------------------------+-----------+
# |  6 | kosher                 | 0.0102149 |
# +----+------------------------+-----------+
# |  7 | meat-based             | 0.0102149 |
# +----+------------------------+-----------+
# |  8 | pescatarian            | 0.0102149 |
# +----+------------------------+-----------+
# |  9 | seafood-based          | 0.0102149 |
# +----+------------------------+-----------+
# | 10 | vegan                  | 0.887636  |
# +----+------------------------+-----------+
# | 11 | vegetarian             | 0.0102149 |
# +----+------------------------+-----------+
# +--------------------------------------+-----------------------------+
# | cultural_restriction                 |   phi(cultural_restriction) |
# +======================================+=============================+
# | cultural_restriction(NotRestriction) |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(alcohol-based)  |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(dairy)          |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(dessert)        |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(grain-based)    |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(halal)          |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(kosher)         |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(meat-based)     |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(pescatarian)    |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(seafood-based)  |                      0.0102 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(vegan)          |                      0.8876 |
# +--------------------------------------+-----------------------------+
# | cultural_restriction(vegetarian)     |                      0.0102 |
# +--------------------------------------+-----------------------------+
# ------------------------------------------
# Cause: current_working_status:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+--------------------------+-----------+
# |    | current_working_status   |         p |
# +====+==========================+===========+
# |  0 | Full-time-worker         | 0.436078  |
# +----+--------------------------+-----------+
# |  1 | Half-time-worker         | 0.0283503 |
# +----+--------------------------+-----------+
# |  2 | Self-employee            | 0.196037  |
# +----+--------------------------+-----------+
# |  3 | Unemployed               | 0.339534  |
# +----+--------------------------+-----------+
# +------------------------------------------+-------------------------------+
# | current_working_status                   |   phi(current_working_status) |
# +==========================================+===============================+
# | current_working_status(Full-time-worker) |                        0.4361 |
# +------------------------------------------+-------------------------------+
# | current_working_status(Half-time-worker) |                        0.0284 |
# +------------------------------------------+-------------------------------+
# | current_working_status(Self-employee)    |                        0.1960 |
# +------------------------------------------+-------------------------------+
# | current_working_status(Unemployed)       |                        0.3395 |
# +------------------------------------------+-------------------------------+
# ------------------------------------------
# Cause: ethnicity:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-------------+-----------+
# |    | ethnicity   |         p |
# +====+=============+===========+
# |  0 | Asian       | 0.0980839 |
# +----+-------------+-----------+
# |  1 | Black       | 0.171989  |
# +----+-------------+-----------+
# |  2 | Latino      | 0.204836  |
# +----+-------------+-----------+
# |  3 | White       | 0.525091  |
# +----+-------------+-----------+
# +-------------------+------------------+
# | ethnicity         |   phi(ethnicity) |
# +===================+==================+
# | ethnicity(Asian)  |           0.0981 |
# +-------------------+------------------+
# | ethnicity(Black)  |           0.1720 |
# +-------------------+------------------+
# | ethnicity(Latino) |           0.2048 |
# +-------------------+------------------+
# | ethnicity(White)  |           0.5251 |
# +-------------------+------------------+
# ------------------------------------------
# Cause: life_style:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-------------------+-----------+
# |    | life_style        |         p |
# +====+===================+===========+
# |  0 | Lightly active    | 0.0653574 |
# +----+-------------------+-----------+
# |  1 | Moderately active | 0.523866  |
# +----+-------------------+-----------+
# |  2 | Sedentary         | 0.0103861 |
# +----+-------------------+-----------+
# |  3 | Very active       | 0.40039   |
# +----+-------------------+-----------+
# +-------------------------------+-------------------+
# | life_style                    |   phi(life_style) |
# +===============================+===================+
# | life_style(Lightly active)    |            0.0654 |
# +-------------------------------+-------------------+
# | life_style(Moderately active) |            0.5239 |
# +-------------------------------+-------------------+
# | life_style(Sedentary)         |            0.0104 |
# +-------------------------------+-------------------+
# | life_style(Very active)       |            0.4004 |
# +-------------------------------+-------------------+
# ------------------------------------------
# Cause: marital_status:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+------------------+----------+
# |    | marital_status   |        p |
# +====+==================+==========+
# |  0 | Married          | 0.498012 |
# +----+------------------+----------+
# |  1 | Single           | 0.501988 |
# +----+------------------+----------+
# +-------------------------+-----------------------+
# | marital_status          |   phi(marital_status) |
# +=========================+=======================+
# | marital_status(Married) |                0.4980 |
# +-------------------------+-----------------------+
# | marital_status(Single)  |                0.5020 |
# +-------------------------+-----------------------+
# ------------------------------------------
# Cause: next_BMI:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-------------+-----------+
# |    | next_BMI    |         p |
# +====+=============+===========+
# |  0 | healthy     | 0.587591  |
# +----+-------------+-----------+
# |  1 | obesity     | 0.0350926 |
# +----+-------------+-----------+
# |  2 | overweight  | 0.286075  |
# +----+-------------+-----------+
# |  3 | underweight | 0.0912409 |
# +----+-------------+-----------+
# +-----------------------+-----------------+
# | next_BMI              |   phi(next_BMI) |
# +=======================+=================+
# | next_BMI(healthy)     |          0.5876 |
# +-----------------------+-----------------+
# | next_BMI(obesity)     |          0.0351 |
# +-----------------------+-----------------+
# | next_BMI(overweight)  |          0.2861 |
# +-----------------------+-----------------+
# | next_BMI(underweight) |          0.0912 |
# +-----------------------+-----------------+
# ------------------------------------------
# Cause: nutrition_goal:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+------------------+-------------+
# |    | nutrition_goal   |           p |
# +====+==================+=============+
# |  0 | gain_weight      | 0.000966119 |
# +----+------------------+-------------+
# |  1 | lose_weight      | 0.0680864   |
# +----+------------------+-------------+
# |  2 | maintain_fit     | 0.930948    |
# +----+------------------+-------------+
# +------------------------------+-----------------------+
# | nutrition_goal               |   phi(nutrition_goal) |
# +==============================+=======================+
# | nutrition_goal(gain_weight)  |                0.0010 |
# +------------------------------+-----------------------+
# | nutrition_goal(lose_weight)  |                0.0681 |
# +------------------------------+-----------------------+
# | nutrition_goal(maintain_fit) |                0.9309 |
# +------------------------------+-----------------------+
# ------------------------------------------
# Cause: meal_type_y:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------------------------------------------------------------------------------+------------+
# |    | meal_type_y                                                                           |          p |
# +====+=======================================================================================+============+
# |  0 | Appetizer                                                                             | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  1 | Basic                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  2 | Beverage                                                                              | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  3 | Biscuits                                                                              | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  4 | Breakfast                                                                             | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  5 | Cocktail                                                                              | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  6 | Dessert                                                                               | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  7 | Fruit-based                                                                           | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  8 | Grain-based                                                                           | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# |  9 | Herb-based                                                                            | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 10 | Meat-based                                                                            | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 11 | NotInformation                                                                        | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 12 | Pickles                                                                               | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 13 | Seafood                                                                               | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 14 | Seafood-based                                                                         | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 15 | Snack                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 16 | Spicy                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 17 | This recipe is meat-based.                                                            | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 18 | Vegan                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 19 | Vegetarian                                                                            | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 20 | appetizer                                                                             | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 21 | baked goods                                                                           | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 22 | baking                                                                                | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 23 | based on the ingredients provided, the meal type of the recipe would be "vegetarian." | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 24 | beverage                                                                              | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 25 | bread                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 26 | breakfast                                                                             | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 27 | breakfast;lunch;dinner                                                                | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 28 | caprese                                                                               | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 29 | cheese                                                                                | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 30 | dairy                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 31 | dessert                                                                               | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 32 | dinner                                                                                | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 33 | fish-based                                                                            | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 34 | fruit                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 35 | fruit-based                                                                           | 0.0405645  |
# +----+---------------------------------------------------------------------------------------+------------+
# | 36 | grain-based                                                                           | 0.0915574  |
# +----+---------------------------------------------------------------------------------------+------------+
# | 37 | greek                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 38 | indian                                                                                | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 39 | kosher                                                                                | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 40 | lunch                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 41 | lunch;dinner                                                                          | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 42 | meat                                                                                  | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 43 | meat-based                                                                            | 0.0020747  |
# +----+---------------------------------------------------------------------------------------+------------+
# | 44 | mexican                                                                               | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 45 | non-vegetarian                                                                        | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 46 | omelette                                                                              | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 47 | pasta                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 48 | pizza                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 49 | salad                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 50 | sandwich.                                                                             | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 51 | seafood                                                                               | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 52 | smoothie                                                                              | 0.00648754 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 53 | snack                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 54 | sushi                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 55 | the meal type of this recipe is "dessert".                                            | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 56 | the meal type of this recipe is meat-based.                                           | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 57 | the meal types for the provided recipes are seafood-based or sushi-based.             | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 58 | there is no specific indication of the meal type in the given recipe.                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 59 | this recipe can be classified as seafood-based.                                       | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 60 | this recipe is a meat-based recipe.                                                   | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 61 | this recipe is vegetarian.                                                            | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 62 | toast                                                                                 | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# | 63 | vegan                                                                                 | 0.314651   |
# +----+---------------------------------------------------------------------------------------+------------+
# | 64 | vegetarian                                                                            | 0.212666   |
# +----+---------------------------------------------------------------------------------------+------------+
# | 65 | veggie                                                                                | 0.222227   |
# +----+---------------------------------------------------------------------------------------+------------+
# | 66 | veggie/vegetarian                                                                     | 0.00182954 |
# +----+---------------------------------------------------------------------------------------+------------+
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y                                                                                        |   phi(meal_type_y) |
# +====================================================================================================+====================+
# | meal_type_y(Appetizer)                                                                             |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Basic)                                                                                 |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Beverage)                                                                              |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Biscuits)                                                                              |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Breakfast)                                                                             |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Cocktail)                                                                              |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Dessert)                                                                               |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Fruit-based)                                                                           |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Grain-based)                                                                           |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Herb-based)                                                                            |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Meat-based)                                                                            |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(NotInformation)                                                                        |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Pickles)                                                                               |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# | meal_type_y(Seafood)                                                                               |             0.0018 |
# +----------------------------------------------------------------------------------------------------+--------------------+
# ...
# |  5 |               5 | 0.00272351 |
# +----+-----------------+------------+
# |  6 |               9 | 0.00274244 |
# +----+-----------------+------------+
# +------------------+----------------------+
# | carbohydrates    |   phi(carbohydrates) |
# +==================+======================+
# | carbohydrates(0) |               0.0030 |
# +------------------+----------------------+
# | carbohydrates(1) |               0.8747 |
# +------------------+----------------------+
# | carbohydrates(2) |               0.1102 |
# +------------------+----------------------+
# | carbohydrates(3) |               0.0039 |
# +------------------+----------------------+
# | carbohydrates(4) |               0.0027 |
# +------------------+----------------------+
# | carbohydrates(5) |               0.0027 |
# +------------------+----------------------+
# | carbohydrates(9) |               0.0027 |
# +------------------+----------------------+
# ------------------------------------------
# Cause: current_daily_calories:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+--------------------------+------------+
# |    |   current_daily_calories |          p |
# +====+==========================+============+
# |  0 |                        0 | 0.00233494 |
# +----+--------------------------+------------+
# |  1 |                        1 | 0.00360248 |
# +----+--------------------------+------------+
# |  2 |                        2 | 0.00981221 |
# +----+--------------------------+------------+
# |  3 |                        3 | 0.0156937  |
# +----+--------------------------+------------+
# |  4 |                        4 | 0.648599   |
# +----+--------------------------+------------+
# |  5 |                        5 | 0.283948   |
# +----+--------------------------+------------+
# |  6 |                        6 | 0.0158354  |
# +----+--------------------------+------------+
# |  7 |                        7 | 0.00672463 |
# +----+--------------------------+------------+
# |  8 |                        8 | 0.00672463 |
# +----+--------------------------+------------+
# |  9 |                        9 | 0.00672463 |
# +----+--------------------------+------------+
# +---------------------------+-------------------------------+
# | current_daily_calories    |   phi(current_daily_calories) |
# +===========================+===============================+
# | current_daily_calories(0) |                        0.0023 |
# +---------------------------+-------------------------------+
# | current_daily_calories(1) |                        0.0036 |
# +---------------------------+-------------------------------+
# | current_daily_calories(2) |                        0.0098 |
# +---------------------------+-------------------------------+
# | current_daily_calories(3) |                        0.0157 |
# +---------------------------+-------------------------------+
# | current_daily_calories(4) |                        0.6486 |
# +---------------------------+-------------------------------+
# | current_daily_calories(5) |                        0.2839 |
# +---------------------------+-------------------------------+
# | current_daily_calories(6) |                        0.0158 |
# +---------------------------+-------------------------------+
# | current_daily_calories(7) |                        0.0067 |
# +---------------------------+-------------------------------+
# | current_daily_calories(8) |                        0.0067 |
# +---------------------------+-------------------------------+
# | current_daily_calories(9) |                        0.0067 |
# +---------------------------+-------------------------------+
# ------------------------------------------
# Cause: fat:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-------+-----------+
# |    |   fat |         p |
# +====+=======+===========+
# |  0 |     0 | 0.0175113 |
# +----+-------+-----------+
# |  1 |     1 | 0.894932  |
# +----+-------+-----------+
# |  2 |     2 | 0.0175113 |
# +----+-------+-----------+
# |  3 |     3 | 0.0175113 |
# +----+-------+-----------+
# |  4 |     4 | 0.0175113 |
# +----+-------+-----------+
# |  5 |     5 | 0.0175113 |
# +----+-------+-----------+
# |  6 |     9 | 0.0175113 |
# +----+-------+-----------+
# +--------+------------+
# | fat    |   phi(fat) |
# +========+============+
# | fat(0) |     0.0175 |
# +--------+------------+
# | fat(1) |     0.8949 |
# +--------+------------+
# | fat(2) |     0.0175 |
# +--------+------------+
# | fat(3) |     0.0175 |
# +--------+------------+
# | fat(4) |     0.0175 |
# +--------+------------+
# | fat(5) |     0.0175 |
# +--------+------------+
# | fat(9) |     0.0175 |
# +--------+------------+
# ------------------------------------------
# Cause: fiber:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------+------------+
# |    |   fiber |          p |
# +====+=========+============+
# |  0 |       0 | 0.0531912  |
# +----+---------+------------+
# |  1 |       1 | 0.713101   |
# +----+---------+------------+
# |  2 |       2 | 0.158276   |
# +----+---------+------------+
# |  3 |       3 | 0.0540253  |
# +----+---------+------------+
# |  4 |       4 | 0.00648674 |
# +----+---------+------------+
# |  5 |       5 | 0.00356771 |
# +----+---------+------------+
# |  6 |       6 | 0.0033592  |
# +----+---------+------------+
# |  7 |       7 | 0.0027337  |
# +----+---------+------------+
# |  8 |       8 | 0.0029422  |
# +----+---------+------------+
# |  9 |       9 | 0.00231669 |
# +----+---------+------------+
# +----------+--------------+
# | fiber    |   phi(fiber) |
# +==========+==============+
# | fiber(0) |       0.0532 |
# +----------+--------------+
# | fiber(1) |       0.7131 |
# +----------+--------------+
# | fiber(2) |       0.1583 |
# +----------+--------------+
# | fiber(3) |       0.0540 |
# +----------+--------------+
# | fiber(4) |       0.0065 |
# +----------+--------------+
# | fiber(5) |       0.0036 |
# +----------+--------------+
# | fiber(6) |       0.0034 |
# +----------+--------------+
# | fiber(7) |       0.0027 |
# +----------+--------------+
# | fiber(8) |       0.0029 |
# +----------+--------------+
# | fiber(9) |       0.0023 |
# +----------+--------------+
# ------------------------------------------
# Cause: height:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+----------+-------------+
# |    |   height |           p |
# +====+==========+=============+
# |  0 |        0 | 0.00281837  |
# +----+----------+-------------+
# |  1 |        2 | 0.000304675 |
# +----+----------+-------------+
# |  2 |        3 | 0.00233812  |
# +----+----------+-------------+
# |  3 |        4 | 0.00138769  |
# +----+----------+-------------+
# |  4 |        5 | 0.000673274 |
# +----+----------+-------------+
# |  5 |        6 | 0.00788199  |
# +----+----------+-------------+
# |  6 |        7 | 0.125812    |
# +----+----------+-------------+
# |  7 |        8 | 0.85678     |
# +----+----------+-------------+
# |  8 |        9 | 0.00200319  |
# +----+----------+-------------+
# +-----------+---------------+
# | height    |   phi(height) |
# +===========+===============+
# | height(0) |        0.0028 |
# +-----------+---------------+
# | height(2) |        0.0003 |
# +-----------+---------------+
# | height(3) |        0.0023 |
# +-----------+---------------+
# | height(4) |        0.0014 |
# +-----------+---------------+
# | height(5) |        0.0007 |
# +-----------+---------------+
# | height(6) |        0.0079 |
# +-----------+---------------+
# | height(7) |        0.1258 |
# +-----------+---------------+
# | height(8) |        0.8568 |
# +-----------+---------------+
# | height(9) |        0.0020 |
# +-----------+---------------+
# ------------------------------------------
# Cause: price:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------+------------+
# |    |   price |          p |
# +====+=========+============+
# |  0 |       0 | 0.0693932  |
# +----+---------+------------+
# |  1 |       5 | 0.912535   |
# +----+---------+------------+
# |  2 |       7 | 0.00779566 |
# +----+---------+------------+
# |  3 |       9 | 0.0102761  |
# +----+---------+------------+
# +----------+--------------+
# | price    |   phi(price) |
# +==========+==============+
# | price(0) |       0.0694 |
# +----------+--------------+
# | price(5) |       0.9125 |
# +----------+--------------+
# | price(7) |       0.0078 |
# +----------+--------------+
# | price(9) |       0.0103 |
# +----------+--------------+
# ------------------------------------------
# Cause: projected_daily_calories:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+----------------------------+-------------+
# |    |   projected_daily_calories |           p |
# +====+============================+=============+
# |  0 |                          0 | 0.00420096  |
# +----+----------------------------+-------------+
# |  1 |                          1 | 0.000109379 |
# +----+----------------------------+-------------+
# |  2 |                          2 | 0.000536821 |
# +----+----------------------------+-------------+
# |  3 |                          3 | 0.00472034  |
# +----+----------------------------+-------------+
# |  4 |                          4 | 0.0111865   |
# +----+----------------------------+-------------+
# |  5 |                          5 | 0.376292    |
# +----+----------------------------+-------------+
# |  6 |                          6 | 0.571655    |
# +----+----------------------------+-------------+
# |  7 |                          7 | 0.0198724   |
# +----+----------------------------+-------------+
# |  8 |                          8 | 0.00571331  |
# +----+----------------------------+-------------+
# |  9 |                          9 | 0.00571331  |
# +----+----------------------------+-------------+
# +-----------------------------+---------------------------------+
# | projected_daily_calories    |   phi(projected_daily_calories) |
# +=============================+=================================+
# | projected_daily_calories(0) |                          0.0042 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(1) |                          0.0001 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(2) |                          0.0005 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(3) |                          0.0047 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(4) |                          0.0112 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(5) |                          0.3763 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(6) |                          0.5717 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(7) |                          0.0199 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(8) |                          0.0057 |
# +-----------------------------+---------------------------------+
# | projected_daily_calories(9) |                          0.0057 |
# +-----------------------------+---------------------------------+
# ------------------------------------------
# Cause: protein:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-----------+------------+
# |    |   protein |          p |
# +====+===========+============+
# |  0 |         0 | 0.00925408 |
# +----+-----------+------------+
# |  1 |         1 | 0.966278   |
# +----+-----------+------------+
# |  2 |         2 | 0.00819951 |
# +----+-----------+------------+
# |  3 |         3 | 0.00379674 |
# +----+-----------+------------+
# |  4 |         4 | 0.00293831 |
# +----+-----------+------------+
# |  5 |         5 | 0.00213297 |
# +----+-----------+------------+
# |  6 |         6 | 0.00249504 |
# +----+-----------+------------+
# |  7 |         8 | 0.00253916 |
# +----+-----------+------------+
# |  8 |         9 | 0.00236641 |
# +----+-----------+------------+
# +------------+----------------+
# | protein    |   phi(protein) |
# +============+================+
# | protein(0) |         0.0093 |
# +------------+----------------+
# | protein(1) |         0.9663 |
# +------------+----------------+
# | protein(2) |         0.0082 |
# +------------+----------------+
# | protein(3) |         0.0038 |
# +------------+----------------+
# | protein(4) |         0.0029 |
# +------------+----------------+
# | protein(5) |         0.0021 |
# +------------+----------------+
# | protein(6) |         0.0025 |
# +------------+----------------+
# | protein(8) |         0.0025 |
# +------------+----------------+
# | protein(9) |         0.0024 |
# +------------+----------------+
# ------------------------------------------
# Cause: weight:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+----------+-----------+
# |    |   weight |         p |
# +====+==========+===========+
# |  0 |        0 | 0.0162655 |
# +----+----------+-----------+
# |  1 |        1 | 0.0162655 |
# +----+----------+-----------+
# |  2 |        2 | 0.0162655 |
# +----+----------+-----------+
# |  3 |        3 | 0.0162655 |
# +----+----------+-----------+
# |  4 |        4 | 0.748211  |
# +----+----------+-----------+
# |  5 |        5 | 0.121666  |
# +----+----------+-----------+
# |  6 |        6 | 0.0162655 |
# +----+----------+-----------+
# |  7 |        7 | 0.0162655 |
# +----+----------+-----------+
# |  8 |        8 | 0.0162655 |
# +----+----------+-----------+
# |  9 |        9 | 0.0162655 |
# +----+----------+-----------+
# +-----------+---------------+
# | weight    |   phi(weight) |
# +===========+===============+
# | weight(0) |        0.0163 |
# +-----------+---------------+
# | weight(1) |        0.0163 |
# +-----------+---------------+
# | weight(2) |        0.0163 |
# +-----------+---------------+
# | weight(3) |        0.0163 |
# +-----------+---------------+
# | weight(4) |        0.7482 |
# +-----------+---------------+
# | weight(5) |        0.1217 |
# +-----------+---------------+
# | weight(6) |        0.0163 |
# +-----------+---------------+
# | weight(7) |        0.0163 |
# +-----------+---------------+
# | weight(8) |        0.0163 |
# +-----------+---------------+
# | weight(9) |        0.0163 |
# +-----------+---------------+
# ------------------------------------------
# Cause: cluster:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+-----------+-----------+
# |    |   cluster |         p |
# +====+===========+===========+
# |  0 |         0 | 0.0408597 |
# +----+-----------+-----------+
# |  1 |         2 | 0.0408597 |
# +----+-----------+-----------+
# |  2 |         3 | 0.918281  |
# +----+-----------+-----------+
# +--------------+----------------+
# | cluster      |   phi(cluster) |
# +==============+================+
# | cluster(0.0) |         0.0409 |
# +--------------+----------------+
# | cluster(2.0) |         0.0409 |
# +--------------+----------------+
# | cluster(3.0) |         0.9183 |
# +--------------+----------------+
# ------------------------------------------
# Cause: y_pred:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+----------+------------+
# |    |   y_pred |          p |
# +====+==========+============+
# |  0 |        0 | 0.00186424 |
# +----+----------+------------+
# |  1 |        1 | 0.998136   |
# +----+----------+------------+
# +-----------+---------------+
# | y_pred    |   phi(y_pred) |
# +===========+===============+
# | y_pred(0) |        0.0019 |
# +-----------+---------------+
# | y_pred(1) |        0.9981 |
# +-----------+---------------+
# ------------------------------------------

# %%
#predict
bn.inference.fit(bn_model, variables=['y_pred'], evidence=evidence_like)
# Out:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+----------+------------+
# |    |   y_pred |          p |
# +====+==========+============+
# |  0 |        0 | 0.00194786 |
# +----+----------+------------+
# |  1 |        1 | 0.998052   |
# +----+----------+------------+
# <DiscreteFactor representing phi(y_pred:2) at 0x7e8a227ba380>

# %%
#predict
ev = evidence_dislike.copy()
del ev['y_pred']
bn.inference.fit(bn_model, variables=['y_pred'], evidence=ev)
# Out:
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+----------+-----------+
# |    |   y_pred |         p |
# +====+==========+===========+
# |  0 |        0 | 0.0386463 |
# +----+----------+-----------+
# |  1 |        1 | 0.961354  |
# +----+----------+-----------+
# <DiscreteFactor representing phi(y_pred:2) at 0x7ce808aead70>

# %%
def inverse_standarization(value, mean, std):
  return value*std+mean

# %%
denorm_values = {}
for num in numeric_features:
  denorm_values[num] = {'mean': np.mean(train[num]), 'std': np.std(train[num])}

# %%
denorm_values
# Out:
# {'calories': {'mean': 571.4349842480779, 'std': 714.3788483376305},
#  'carbohydrates': {'mean': 107.38713835129225, 'std': 129.98057203455144},
#  'current_daily_calories': {'mean': 2263.42573452005,
#   'std': 573.5062952549755},
#  'fat': {'mean': 41.901670375741425, 'std': 50.501299734256946},
#  'fiber': {'mean': 10.857418776525828, 'std': 10.766843412056323},
#  'height': {'mean': 165.30459510821268, 'std': 11.611385395816972},
#  'price': {'mean': 1.9086393385950418, 'std': 0.2974992833361969},
#  'projected_daily_calories': {'mean': 2014.0391952359469,
#   'std': 536.7625561351381},
#  'protein': {'mean': 24.83870909724786, 'std': 40.13231411680017},
#  'weight': {'mean': 70.81114269308068, 'std': 16.605729347679265},
#  'day_number': {'mean': 364.46053718645084, 'std': 210.77493117767492},
#  'time_of_meal_consumption': {'mean': 12.9913759746112,
#   'std': 4.549567423495502}}

# %%
inverse_standarization(2.193, denorm_values['fiber']['mean'], denorm_values['fiber']['std'])
# Out:
# 34.469106379165346

# %%
feat='calories'
inverse_standarization(0.647, denorm_values[feat]['mean'], denorm_values[feat]['std'])
# Out:
# 1033.6380991225249

# %%
# save model
path_model = os.path.join(base_path, "bayesian_model", f"bn_model_new_experiment_model_bert.pkl")
bn.save(bn_model, path_model, overwrite=True)
# Out:
# [pypickle] Pickle file saved: [/content/drive/MyDrive/Train expectation model /results/bayesian_model/bn_model_new_experiment_model_bert.pkl]
# True

# %%
factor_df.loc[data_indices[464], :]
# Out:
# BMI                                                  healthy
# age_range                                              40-49
# allergens                                       NotAllergens
# allergy                                             Multiple
# clinical_gender                                            M
# cultural_factor                         vegetarian_observant
# cultural_restriction                                   vegan
# current_working_status                      Half-time-worker
# ethnicity                                             Latino
# life_style                                       Very active
# marital_status                                       Married
# next_BMI                                             healthy
# nutrition_goal                                  maintain_fit
# meal_type_y                                           veggie
# taste                                                  umami
# place_of_meal_consumption                               home
# social_situation_of_meal_consumption                 friends
# calories                                                   1
# carbohydrates                                              1
# current_daily_calories                                     6
# fat                                                        1
# fiber                                                      1
# height                                                     7
# price                                                      5
# projected_daily_calories                                   7
# protein                                                    1
# weight                                                     4
# day_number                                                 2
# time_of_meal_consumption                                   3
# cluster                                                  3.0
# y_pred                                                     0
# Name: 857910, dtype: object

# %%
factor_df.loc[data_indices[4], :]
# Out:
# BMI                                              healthy
# age_range                                          50-59
# allergens                                      tree nuts
# allergy                                            wheat
# clinical_gender                                        F
# cultural_factor                          flexi_observant
# cultural_restriction                               vegan
# current_working_status                  Full-time-worker
# ethnicity                                          White
# life_style                                   Very active
# marital_status                                   Married
# next_BMI                                      overweight
# nutrition_goal                              maintain_fit
# meal_type_y                                   vegetarian
# taste                                              sweet
# place_of_meal_consumption                           home
# social_situation_of_meal_consumption               alone
# calories                                               1
# carbohydrates                                          1
# current_daily_calories                                 5
# fat                                                    1
# fiber                                                  1
# height                                                 8
# price                                                  5
# projected_daily_calories                               5
# protein                                                1
# weight                                                 4
# day_number                                             5
# time_of_meal_consumption                               7
# cluster                                              3.0
# y_pred                                                 1
# Name: 312602, dtype: object

# %%
base_path
# Out:
# '/content/drive/MyDrive/Train expectation model /results'

# %%
print(bn_rule_model.get_cpds())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-ed6d2588cf58> in <cell line: 1>()
# ----> 1 print(bn_rule_model.get_cpds())
#
# NameError: name 'bn_rule_model' is not defined

# %%
bn_rule_model.save('bayesian_explanation.bif', filetype='bif')

# %%
def process_names(name:str, numeric_features, categorical_features):
  new_name = name
  new_name = new_name.replace('scaler__', '')
  new_name = new_name.replace('onehot__', '')
  for num in numeric_features:
    check_presence = name.find(num)
    if check_presence != -1:
      new_name = name.split('_')[-1]
      return num
  for cat in categorical_features:
    check_presence = name.find(cat)
    if check_presence != -1:
      feat_name = name[check_presence:check_presence+len(cat)]
      conclusion = name[check_presence+len(cat)+1:]
      new_name = f"{feat_name} = {conclusion}"
      return cat
  new_name = new_name.replace('scaler__', '')

  return new_name

# %% [markdown]
# ## Preprocess data

# %%
import string
import re
def replace_bad_characters(text: str):
  new_text = text.lower()
  new_text = new_text.replace('.', '')
  new_text = re.sub(' +', '_', new_text)
  new_text = new_text.replace(';', '_')
  new_text = new_text.replace(',', '_')
  new_text = new_text.replace(' ', '_')
  new_text = new_text.replace('/', '_')
  new_text = new_text.replace('-', '_')
  #new_text = text.translate(str.maketrans('', '', string.punctuation))
  return new_text

# %%
preprocessor = ColumnTransformer(
    [
        ('onehot', OneHotEncoder(), categorical_features),
        ('scaler', StandardScaler(), numeric_features)
    ],
    remainder='drop'
)

# %%
# sample de data
train_sample = train.sample(10000, random_state=41)

# %%
# load embeddings
chosen_embedding = chosser.selected_value
model_type = "Baseline"
base_path = '/content/drive/MyDrive/Train expectation model /results'
ca = ClusterAnalysis()
cluster_path = os.path.join(base_path,"cluster_analysis", f"new_experiment_{chosen_embedding}_cluster_{model_type}.pkl")
ca.load_cluster_model(cluster_path)

# %%
emb = chosser.loaded_value

# %%
train_sample['embedding'] = train_sample['recipeId'].apply(lambda x: emb.get(x, np.NaN))
mask = train_sample['embedding'].isna()
print(f"number empty: {sum(mask)}")
filtered_sample = train_sample.loc[~mask, :]
# Out:
# number empty: 32

# %%
X = np.vstack(filtered_sample['embedding'].tolist())

# %%
X.shape
# Out:
# (9968, 768)

# %%
filtered_sample['meal_type_y'] = filtered_sample['meal_type_y'].apply(lambda x: replace_bad_characters(x))

# %%
def replace_not_information(x: str):
  if x == "notinformation":
    return "NotInformation"
  else:
    return x

# %%
filtered_sample['meal_type_y'] = filtered_sample['meal_type_y'].apply(lambda x: replace_not_information(x))

# %%
cluster_predictions = ca.predict(X)

# %%
np.unique(cluster_predictions, return_counts=True)
# Out:
# (array([0, 1, 3], dtype=int32), array([   8, 9607,  353]))

# %%
in_features = preprocessor.fit_transform(filtered_sample)

# %%
dense_feat = in_features.toarray()

# %%
cluster_predictions
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
final_feature = np.column_stack((dense_feat, cluster_predictions))

# %%
final_feature.shape
# Out:
# (9968, 221)

# %%
pre_features_names = preprocessor.get_feature_names_out()

# %%
rules = rule_set.get_rules()

# %%
features_names = [r.get_feature_name() for r in rules]

# %%
features_names = {}
for r in rules:
  features_names.update(dict(zip(r.get_feature_name(), r.get_feature_idx())))

# %%
set(features_names)-set(pre_features_names)
# Out:
# {'cluster'}

# %%
feature_name_to_idx = {}
for key in features_names.keys():
  if key != 'cluster':
    feature_name_to_idx[key] = pre_features_names.tolist().index(key)
  else:
    feature_name_to_idx[key] = len(pre_features_names)

# %%
def update_rules_index(rule_list, dict_feature_idx):
  new_rule_list = []
  for rule in rule_list:
    clauses = rule.premise.clauses
    for expr in clauses:
      expr.feature_idx = dict_feature_idx.get(expr.get_feature_name())

# %%
rule_set.rules[0].premise.clauses[0].feature_idx =
# Out:
# 127
